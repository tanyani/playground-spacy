# %%
import os 
import spacy
import re
import pandas as pd

nlp = spacy.load('en_core_web_sm')

files = [f for f in os.listdir("data/") if f.endswith('txt')]
def readFiles(filename='5369.txt', dirname='data/'):
    return open(dirname+filename).read().replace('\n', ' ')
def stitch_words(text):
    return re.sub(r'- ',r'', text)
def getNC(doc):
    return [[chunk.text, chunk.root.text, chunk.root.dep_,
              chunk.root.head.text] for chunk in doc.noun_chunks]
def getNER(doc):
    return [[ents.text, ents.label_, ents.start, ents.end] for ents in doc.ents]

# %%
df = pd.DataFrame(files, columns=['filename'])
df['rawContent'] = [stitch_words(readFiles(i)) for i in df.filename]
df['doc'] = [nlp(i) for i in df.rawContent]
df['NC'] = [getNC(i) for i in df.doc]
df['NER'] = [getNER(i) for i in df.doc]
df.head()
# Out:
#    filename                                         rawContent  \
# 0  1003.txt  ORIGINAL ARTICLE The Epidemiology of Panic Att...
# 1  1007.txt  ORIGINAL ARTICLE Lifetime Prevalence and Age-o...
# 2  1005.txt  MarketWatch Medicaid Cost Containment And Acce...
# 3  1006.txt  Unmet Need for Personal Assistance Services: E...
# 4  1001.txt  ANNALS OF FAMILY MEDICINE  WWW.ANNFAMMED.ORG  ...
#
#                                                  doc  \
# 0  (ORIGINAL, ARTICLE, The, Epidemiology, of, Pan...
# 1  (ORIGINAL, ARTICLE, Lifetime, Prevalence, and,...
# 2  (MarketWatch, Medicaid, Cost, Containment, And...
# 3  (Unmet, Need, for, Personal, Assistance, Servi...
# 4  (ANNALS, OF, FAMILY, MEDICINE,  , WWW.ANNFAMME...
#
#                                                   NC  \
# 0  [[ORIGINAL ARTICLE, ARTICLE, ROOT, ARTICLE], [...
# 1  [[ORIGINAL ARTICLE Lifetime Prevalence, Preval...
# 2  [[MarketWatch Medicaid Cost Containment, Conta...
# 3  [[Unmet, Unmet, nsubj, Need], [Personal Assist...
# 4  [[FAMILY MEDICINE, MEDICINE, pobj, OF], [AUGUS...
#
#                                                  NER
# 0  [[Panic Disorder, ORG, 8, 10], [Agoraphobia, G...
# 1  [[the National Comorbidity Survey Replication ...
# 2  [[MarketWatch Medicaid Cost Containment And Ac...
# 3  [[Hours, TIME, 11, 12], [Mitchell P. LaPlante,...
# 4  [[FAMILY MEDICINE, ORG, 2, 4], [1, CARDINAL, 9...

# %%
df['NERF'] = [[e for e in i if e[1]=='ORG'] for i in df.NER]

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

df['sents'] = [[nlp(j) for j in sent_tokenize(i)] for i in df.rawContent]
df.head()
# Out:
#    filename                                         rawContent  \
# 0  1003.txt  ORIGINAL ARTICLE The Epidemiology of Panic Att...
# 1  1007.txt  ORIGINAL ARTICLE Lifetime Prevalence and Age-o...
# 2  1005.txt  MarketWatch Medicaid Cost Containment And Acce...
# 3  1006.txt  Unmet Need for Personal Assistance Services: E...
# 4  1001.txt  ANNALS OF FAMILY MEDICINE  WWW.ANNFAMMED.ORG  ...
#
#                                                  doc  \
# 0  (ORIGINAL, ARTICLE, The, Epidemiology, of, Pan...
# 1  (ORIGINAL, ARTICLE, Lifetime, Prevalence, and,...
# 2  (MarketWatch, Medicaid, Cost, Containment, And...
# 3  (Unmet, Need, for, Personal, Assistance, Servi...
# 4  (ANNALS, OF, FAMILY, MEDICINE,  , WWW.ANNFAMME...
#
#                                                   NC  \
# 0  [[ORIGINAL ARTICLE, ARTICLE, ROOT, ARTICLE], [...
# 1  [[ORIGINAL ARTICLE Lifetime Prevalence, Preval...
# 2  [[MarketWatch Medicaid Cost Containment, Conta...
# 3  [[Unmet, Unmet, nsubj, Need], [Personal Assist...
# 4  [[FAMILY MEDICINE, MEDICINE, pobj, OF], [AUGUS...
#
#                                                  NER  \
# 0  [[Panic Disorder, ORG, 8, 10], [Agoraphobia, G...
# 1  [[the National Comorbidity Survey Replication ...
# 2  [[MarketWatch Medicaid Cost Containment And Ac...
# 3  [[Hours, TIME, 11, 12], [Mitchell P. LaPlante,...
# 4  [[FAMILY MEDICINE, ORG, 2, 4], [1, CARDINAL, 9...
#
#                                                 NERF  \
# 0  [[Panic Disorder, ORG, 8, 10], [the National C...
# 1  [[the National Comorbidity Survey Replication ...
# 2  [[MarketWatch Medicaid Cost Containment And Ac...
# 3  [[Charlene Harrington Disability Statistics Ce...
# 4  [[FAMILY MEDICINE, ORG, 2, 4], [HMO, ORG, 43, ...
#
#                                                sents
# 0  [(ORIGINAL, ARTICLE, The, Epidemiology, of, Pa...
# 1  [(ORIGINAL, ARTICLE, Lifetime, Prevalence, and...
# 2  [(MarketWatch, Medicaid, Cost, Containment, An...
# 3  [(Unmet, Need, for, Personal, Assistance, Serv...
# 4  [(ANNALS, OF, FAMILY, MEDICINE,  , WWW.ANNFAMM...

# %%
df.head()
# Out:
#    filename                                         rawContent  \
# 0  1003.txt  ORIGINAL ARTICLE The Epidemiology of Panic Att...
# 1  1007.txt  ORIGINAL ARTICLE Lifetime Prevalence and Age-o...
# 2  1005.txt  MarketWatch Medicaid Cost Containment And Acce...
# 3  1006.txt  Unmet Need for Personal Assistance Services: E...
# 4  1001.txt  ANNALS OF FAMILY MEDICINE  WWW.ANNFAMMED.ORG  ...
#
#                                                  doc  \
# 0  (ORIGINAL, ARTICLE, The, Epidemiology, of, Pan...
# 1  (ORIGINAL, ARTICLE, Lifetime, Prevalence, and,...
# 2  (MarketWatch, Medicaid, Cost, Containment, And...
# 3  (Unmet, Need, for, Personal, Assistance, Servi...
# 4  (ANNALS, OF, FAMILY, MEDICINE,  , WWW.ANNFAMME...
#
#                                                   NC  \
# 0  [[ORIGINAL ARTICLE, ARTICLE, ROOT, ARTICLE], [...
# 1  [[ORIGINAL ARTICLE Lifetime Prevalence, Preval...
# 2  [[MarketWatch Medicaid Cost Containment, Conta...
# 3  [[Unmet, Unmet, nsubj, Need], [Personal Assist...
# 4  [[FAMILY MEDICINE, MEDICINE, pobj, OF], [AUGUS...
#
#                                                  NER  \
# 0  [[Panic Disorder, ORG, 8, 10], [Agoraphobia, G...
# 1  [[the National Comorbidity Survey Replication ...
# 2  [[MarketWatch Medicaid Cost Containment And Ac...
# 3  [[Hours, TIME, 11, 12], [Mitchell P. LaPlante,...
# 4  [[FAMILY MEDICINE, ORG, 2, 4], [1, CARDINAL, 9...
#
#                                                 NERF  \
# 0  [[Panic Disorder, ORG, 8, 10], [the National C...
# 1  [[the National Comorbidity Survey Replication ...
# 2  [[MarketWatch Medicaid Cost Containment And Ac...
# 3  [[Charlene Harrington Disability Statistics Ce...
# 4  [[FAMILY MEDICINE, ORG, 2, 4], [HMO, ORG, 43, ...
#
#                                                 docF  \
# 0  ORIGINAL ARTICLE The Epidemiology of Panic Att...
# 1  ORIGINAL ARTICLE The Epidemiology of Panic Att...
# 2  ORIGINAL ARTICLE The Epidemiology of Panic Att...
# 3  ORIGINAL ARTICLE The Epidemiology of Panic Att...
# 4  ORIGINAL ARTICLE The Epidemiology of Panic Att...
#
#                                                sents
# 0  [(ORIGINAL, ARTICLE, The, Epidemiology, of, Pa...
# 1  [(ORIGINAL, ARTICLE, Lifetime, Prevalence, and...
# 2  [(MarketWatch, Medicaid, Cost, Containment, An...
# 3  [(Unmet, Need, for, Personal, Assistance, Serv...
# 4  [(ANNALS, OF, FAMILY, MEDICINE,  , WWW.ANNFAMM...

# %%
df.docF[0]
# Out:
# 'ORIGINAL ARTICLE The Epidemiology of Panic Attacks , <NER> , and <NER> in <NER> , <NER> ; <NER> , AM ; <NER> , <NER> ; <NER> , <NER> ; <NER> , <NER> ; <NER> , <NER> : Only limited information exists about the epidemiology of <NER> panic attacks ( PAs ) and panic disorder ( <NER> ) . Objective : To present nationally representative data about the epidemiology of PAs and <NER> with or without agoraphobia ( <NER> ) on the basis of <NER> findings . Design and Setting : Nationally representative faceto - face household survey conducted using the fully structured <NER> . Participants : <NER> - speaking respondents ( N=9282 ) <NER> . Main Outcome Measures : RespondentswhometDSMIV lifetime criteria for PAs and <NER> with and without <NER> . Results : <NER> prevalence estimates are <NER> for isolated panic without <NER> only ) , <NER> for <NER> with <NER> without <NER> ) , <NER> for <NER> without <NER> ( <NER> only ) , and <NER> for <NER> ) . <NER> , lifetime number of attacks , and number of <NER> with attacks increase monotonically across these <NER> subgroups . All <NER> subgroups are significantly comorbid with other lifetime <NER> disorders , with the highest odds for <NER> and the lowest for <NER> only . Scores on <NER> are also highest for <NER> ( <NER> moderate or severe ) and lowest for <NER> only ( <NER> moderate or severe ) . <NER> is associated with substantial severity , impairment , and comorbidity . <NER> treatment is high ( from <NER> for <NER> to <NER> for <NER> only ) , but <NER> treatment meeting published treatment guidelines is low ( from <NER> for <NER> to <NER> for <NER> only ) . Conclusion : Although the major societal burden of panic is caused by <NER> and <NER> , isolated PAs also have high prevalence and meaningful role impairment . <NER> . <NER> - 424 EPIDEMIOLOGICAL SURVEY INvestigators have helped advance understanding of panic by studying the prevalence and distribution,1 - <NER> onset and course,4 associations with comorbid <NER> and societal costs.8,9 Despite these advances , important questions remain unanswered about the epidemiology of panic,10 among the most important of them regarding the finding that many people have isolated panic attacks ( PAs ) that do not meet criteria for panic disorder ( <NER> ) . These people have elevated prevalence of other mental disorders.6,11 They report greater impairment , use of psychotropic medication , and psychiatric help - seeking than people with many <NER> I disorders.8 Such findings have led to the view that PAs are fairly nonspecific risk markers for psychopathology.12 Some people with isolated PAs meet criteria for agoraphobia ( AG).13 It is not known , though , whether the persistent course and poor outcome associated with <NER> among people with PD14 also apply to PAs with <NER> . As a result , the boundary between <NER> and <NER> and the relative role of <NER> within each are not well understood . Investigation and comparison of these symptom presentations in community samplesmighthelpclarifytheseissues . The current report presents initial data of this sort from the recently completed <NER> ( <NER> ) . METHODS SAMPLE The <NER> is a nationally representative survey of <NER> <NER> - speaking household residents18yearsorolderinthecoterminousUnited States . Face - to - face interviews were performed <NER> and <NER> . The response rate was <NER> . <NER> was oral rather Author Affiliations : <NER> , <NER> , <NER> , <NER> ( <NER> and <NER> , <NER> and <NER> , and <NER> ) ; and <NER> and Clinic , <NER> , Pa ( Dr Shear ) . ( <NER> , <NER> 2006 WWW.ARCHGENPSYCHIATRY.COM <NER> © <NER> <NER> . All rights reserved . Downloaded From : http://archpsyc.jamanetwork.com/ on 04/10/2014 \x0c than written to parallel the baseline <NER> procedures . The human subjects committees of <NER> , <NER> ) and <NER> ( <NER> ) approved the <NER> recruitment and consent procedures . Respondents were interviewed in <NER> parts . The part <NER> interview , administered to all respondent ...

# %%
def NERtag(sents):
    tokens = []
    for i in doc:
    #     print (i.ent_iob_)
        if(i.ent_iob_ == 'O'):
            tokens.append(i.text)
        elif (i.ent_iob_ == 'B'):
            tokens.append('<NER>')
        else:
            pass
    return ' '.join(tokens)
    
        
    
# sents = df['sents'][0]
# for s in sents:
#     tokens = []
#     for i in doc:
#     #     print (i.ent_iob_)
#         if(i.ent_iob_ == 'O'):
#             tokens.append(i.text)
#         elif (i.ent_iob_ == 'B'):
#             tokens.append('<NER>')
#         else:
#             pass
#     ' '.join(tokens)

# %%
df['docF'] = [for s in df.doc]

# %%
df['NERF'][0]
# Out:
# [['Panic Disorder', 'ORG', 8, 10],
#  ['the National Comorbidity Survey Replication Ronald C. Kessler',
#   'ORG',
#   14,
#   22],
#  ['MS Context', 'ORG', 51, 53],
#  ['DSM-IV', 'ORG', 62, 65],
#  ['PD', 'ORG', 74, 75],
#  ['PD', 'ORG', 90, 91],
#  ['AG', 'ORG', 96, 97],
#  ['the US National Comorbidity Survey Replication', 'ORG', 102, 108],
#  ['World Health Organization Composite International Diagnostic Interview',
#   'ORG',
#   126,
#   133],
#  ['PD', 'ORG', 158, 159],
#  ['AG', 'ORG', 162, 163],
#  ['Lifetime', 'ORG', 166, 167],
#  ['AG (PA', 'ORG', 176, 179],
#  ['PA', 'ORG', 185, 186],
#  ['AG', 'ORG', 187, 188],
#  ['PD (PA-AG', 'ORG', 189, 194],
#  ['PD', 'ORG', 199, 200],
#  ['AG', 'ORG', 201, 202],
#  ['PD', 'ORG', 203, 204],
#  ['PD with AG (PD-AG', 'ORG', 211, 218],
#  ['Persistence', 'ORG', 220, 221],
#  ['DSM-IV', 'ORG', 249, 252],
#  ['PD-AG', 'ORG', 259, 262],
#  ['PA', 'ORG', 266, 267],
#  ['the Panic Disorder Severity Scale', 'ORG', 271, 276],
#  ['PD-AG', 'ORG', 280, 283],
#  ['PA', 'ORG', 293, 294],
#  ['PD-AG', 'ORG', 324, 327],
#  ['PA', 'ORG', 331, 332],
#  ['12-month', 'ORG', 336, 337],
#  ['PD-AG', 'ORG', 349, 352],
#  ['PA', 'ORG', 356, 357],
#  ['PD', 'ORG', 372, 373],
#  ['PA-AG', 'ORG', 374, 377],
#  ['PD', 'ORG', 466, 467],
#  ['Axis', 'ORG', 497, 498],
#  ['AG', 'ORG', 543, 544],
#  ['AG', 'ORG', 553, 554],
#  ['PA', 'ORG', 562, 563],
#  ['PD', 'ORG', 564, 565],
#  ['AG', 'ORG', 570, 571],
#  ['US National Comorbidity Survey Replication', 'ORG', 602, 607],
#  ['NCS-R', 'ORG', 608, 611],
#  ['NCS-R', 'ORG', 616, 619],
#  ['Consent', 'ORG', 655, 656],
#  ['Department of Health Care Policy', 'ORG', 662, 667],
#  ['Harvard Medical School', 'ORG', 668, 671],
#  ['the Western Psychiatric Institute', 'ORG', 692, 696],
#  ['REPRINTED) ARCH GEN PSYCHIATRY/VOL 63', 'ORG', 708, 716],
#  ['APR', 'ORG', 717, 718],
#  ['American Medical Association', 'ORG', 723, 726],
#  ['NCS', 'ORG', 744, 745],
#  ['Harvard Medical School (Boston', 'ORG', 752, 757],
#  ['the University of Michigan', 'ORG', 761, 765],
#  ['NCS-R', 'ORG', 771, 774],
#  ['NCS-R', 'ORG', 950, 953],
#  ['AG Panic', 'ORG', 961, 963],
#  ['AG', 'ORG', 964, 965],
#  ['the World Mental Health Survey Initiatiave', 'ORG', 968, 974],
#  ['the World Health Organization Composite International Diagnostic Interview',
#   'ORG',
#   976,
#   984],
#  ['CIDI', 'ORG', 1013, 1014],
#  ['PA', 'ORG', 1151, 1152],
#  ['PA', 'ORG', 1205, 1206],
#  ['PD', 'ORG', 1207, 1208],
#  ['AG (PA', 'ORG', 1209, 1212],
#  ['PA', 'ORG', 1215, 1216],
#  ['PD and AG (PA-AG', 'ORG', 1217, 1224],
#  ['PD', 'ORG', 1226, 1227],
#  ['AG', 'ORG', 1228, 1229],
#  ['PD', 'ORG', 1230, 1231],
#  ['PD', 'ORG', 1235, 1236],
#  ['AG', 'ORG', 1237, 1238],
#  ['PD-AG', 'ORG', 1239, 1242],
#  ['PA', 'ORG', 1245, 1246],
#  ['DSM', 'ORG', 1253, 1254],
#  ['PA-AG', 'ORG', 1258, 1261],
#  ['the DSM-IV', 'ORG', 1265, 1269],
#  ['AG', 'ORG', 1270, 1271],
#  ['PD', 'ORG', 1275, 1276],
#  ['AG', 'ORG', 1280, 1281],
#  ['PA', 'ORG', 1285, 1286],
#  ['the Structured Clinical Interview for DSM-IV', 'ORG', 1321, 1329],
#  ['SCID)19', 'ORG', 1330, 1331],
#  ['NCS', 'ORG', 1339, 1340],
#  ['PD', 'ORG', 1356, 1357],
#  ['CIDI', 'ORG', 1411, 1412],
#  ['PA', 'ORG', 1443, 1444],
#  ['PA', 'ORG', 1445, 1446],
#  ['AG', 'ORG', 1460, 1461],
#  ['AG', 'ORG', 1462, 1463],
#  ['The DSM-IV', 'ORG', 1477, 1481],
#  ['PD', 'ORG', 1497, 1498],
#  ['CIDI', 'ORG', 1502, 1503],
#  ['PA', 'ORG', 1524, 1525],
#  ['CIDI', 'ORG', 1535, 1536],
#  ['CIDI', 'ORG', 1555, 1556],
#  ['CIDI', 'ORG', 1564, 1565],
#  ['COURSE', 'ORG', 1584, 1585],
#  ['IMPAIRMENT Respondents', 'ORG', 1589, 1591],
#  ['DSM-IV', 'ORG', 1593, 1596],
#  ['PA', 'ORG', 1599, 1600],
#  ['AOO', 'ORG', 1609, 1610],
#  ['AOO', 'ORG', 1616, 1617],
#  ['the NCS-R. (Question', 'ORG', 1690, 1696],
#  ['PDSS', 'ORG', 1708, 1709],
#  ['PD', 'ORG', 1717, 1718],
#  ['PDSS', 'ORG', 1727, 1728],
#  ['NCS', 'ORG', 1733, 1734],
#  ['CIDI', 'ORG', 1804, 1805],
#  ['SDS', 'ORG', 1807, 1808],
#  ['12-month', 'ORG', 1811, 1812],
#  ['PA', 'ORG', 1832, 1833],
#  ['Interference', 'ORG', 1898, 1899],
#  ['COMORBID DSM-IV DISORDERS', 'ORG', 1941, 1946],
#  ['NCS-R', 'ORG', 1947, 1950],
#  ['DSM-IV', 'ORG', 1958, 1961],
#  ['Organic', 'ORG', 2080, 2081],
#  ['CIDI', 'ORG', 2116, 2117],
#  ['APR', 'ORG', 2137, 2138],
#  ['American Medical Association', 'ORG', 2143, 2146],
#  [' ', 'ORG', 2169, 2170],
#  ['12-month', 'ORG', 2212, 2213],
#  ['12-month', 'ORG', 2339, 2340],
#  ['guidelines.24 Guideline', 'ORG', 2357, 2359],
#  ['PD', 'ORG', 2456, 2457],
#  ['METHODS Cross', 'ORG', 2530, 2532],
#  ['AOO', 'ORG', 2551, 2552],
#  ['analysis27', 'ORG', 2569, 2570],
#  ['DSM-IV', 'ORG', 2580, 2583],
#  ['NCS', 'ORG', 2587, 2588],
#  ['SUDAAN', 'ORG', 2610, 2611],
#  ['PA', 'ORG', 2677, 2678],
#  ['PA', 'ORG', 2686, 2687],
#  ['PA', 'ORG', 2704, 2705],
#  ['PD', 'ORG', 2710, 2711],
#  ['12-month PD', 'ORG', 2718, 2720],
#  ['PA', 'ORG', 2738, 2739],
#  ['PA-AG', 'ORG', 2744, 2747],
#  ['12-month PA-AG', 'ORG', 2754, 2758],
#  ['PD', 'ORG', 2775, 2776],
#  ['PA-AG', 'ORG', 2783, 2786],
#  ['PD-AG', 'ORG', 2791, 2794],
#  ['12-month PD-AG', 'ORG', 2801, 2805],
#  ['COURSE OF ILLNESS', 'ORG', 2806, 2809],
#  ['PA-AG', 'ORG', 2837, 2840],
#  ['PD', 'ORG', 2844, 2845],
#  ['PD-AG', 'ORG', 2851, 2854],
#  ['PD', 'ORG', 2864, 2865],
#  ['PA', 'ORG', 2869, 2870],
#  ['PA-AG', 'ORG', 2875, 2878],
#  ['PD', 'ORG', 2889, 2890],
#  ['PD', 'ORG', 2911, 2912],
#  ['PD', 'ORG', 2930, 2931],
#  ['PD-AG', 'ORG', 2945, 2948],
#  ['PA-AG', 'ORG', 2952, 2955],
#  ['PD', 'ORG', 2963, 2964],
#  ['PA', 'ORG', 3008, 3009],
#  ['P=.03) AG', 'ORG', 3031, 3034],
#  ['PA', 'ORG', 3050, 3051],
#  ['PD', 'ORG', 3065, 3066],
#  ['PA', 'ORG', 3084, 3085],
#  ['PD', 'ORG', 3096, 3097],
#  ['PD-AG', 'ORG', 3102, 3105],
#  ['PA-AG', 'ORG', 3109, 3112],
#  ['Lifetime', 'ORG', 3119, 3120],
#  ['DSM-IV', 'ORG', 3123, 3126],
#  ['PD', 'ORG', 3135, 3136],
#  ['AG', 'ORG', 3142, 3143],
#  ['PA', 'ORG', 3151, 3152],
#  ['PD or AG', 'ORG', 3154, 3157],
#  ['PA-AG', 'ORG', 3158, 3161],
#  ['PA', 'ORG', 3165, 3166],
#  ['AG', 'ORG', 3167, 3168],
#  ['PD', 'ORG', 3170, 3171],
#  ['PD', 'ORG', 3172, 3173],
#  ['PD', 'ORG', 3178, 3179],
#  ['AG', 'ORG', 3180, 3181],
#  ['PD-AG', 'ORG', 3182, 3185],
#  ['PD', 'ORG', 3189, 3190],
#  ['AG', 'ORG', 3191, 3192],
#  ['PD', 'ORG', 3197, 3198],
#  ['PD-AG', 'ORG', 3204, 3207],
#  ['PD', 'ORG', 3222, 3223],
#  ['APR', 'ORG', 3237, 3238],
#  ['American Medical Association', 'ORG', 3243, 3246],
#  ['PD', 'ORG', 3279, 3280],
#  ['the PD-AG', 'ORG', 3294, 3298],
#  ['AOO of PA', 'ORG', 3315, 3318],
#  ['P=.44', 'ORG', 3331, 3332],
#  ['PA AOO', 'ORG', 3336, 3338],
#  ['PD', 'ORG', 3352, 3353],
#  ['AOO of PA', 'ORG', 3361, 3364],
#  ['PD', 'ORG', 3371, 3372],
#  ['PD-AG', 'ORG', 3375, 3378],
#  ['PA', 'ORG', 3396, 3397],
#  ['PA', 'ORG', 3411, 3412],
#  ['PD-AG', 'ORG', 3417, 3420],
#  ['PD', 'ORG', 3435, 3436],
#  ['AG', 'ORG', 3443, 3444],
#  ['AG', 'ORG', 3459, 3460],
#  ['AG', 'ORG', 3479, 3480],
#  ['PD', 'ORG', 3576, 3577],
#  ['PA', 'ORG', 3579, 3580],
#  ['AG', 'ORG', 3595, 3596],
#  ['Respondents', 'ORG', 3659, 3660],
#  ['PA', 'ORG', 3684, 3685],
#  ['PD-AG', 'ORG', 3694, 3697],
#  ['DSM-IV', 'ORG', 3759, 3762],
#  ['PA', 'ORG', 3784, 3785],
#  ['Persistence', 'ORG', 3792, 3793],
#  ['Course of Panic', 'ORG', 3795, 3798],
#  ['PA-AG', 'ORG', 3815, 3818],
#  ['PD-AG', 'ORG', 3830, 3833],
#  ['Lifetime', 'ORG', 3840, 3841],
#  ['Lifetime', 'ORG', 3885, 3886],
#  ['PA', 'ORG', 3910, 3911],
#  ['PD', 'ORG', 3928, 3929],
#  ['NA NA 23.6', 'ORG', 3930, 3933],
#  ['AG', 'ORG', 3941, 3942],
#  ['NA', 'ORG', 3943, 3944],
#  ['Lifetime', 'ORG', 4002, 4003],
#  ['Lifetime', 'ORG', 4023, 4024],
#  ['NA', 'ORG', 4064, 4065],
#  ['NA Abbreviations', 'ORG', 4086, 4088],
#  ['AG', 'ORG', 4089, 4090],
#  ['NA', 'ORG', 4093, 4094],
#  ['PA', 'ORG', 4098, 4099],
#  ['PD', 'ORG', 4103, 4104],
#  ['PA', 'ORG', 4108, 4109],
#  ['PA', 'ORG', 4114, 4115],
#  ['PD or AG', 'ORG', 4118, 4121],
#  ['PA-AG', 'ORG', 4122, 4125],
#  ['PA', 'ORG', 4129, 4130],
#  ['AG', 'ORG', 4131, 4132],
#  ['PD', 'ORG', 4135, 4136],
#  ['PD', 'ORG', 4137, 4138],
#  ['PD', 'ORG', 4143, 4144],
#  ['AG', 'ORG', 4145, 4146],
#  ['PD-AG', 'ORG', 4147, 4150],
#  ['PD', 'ORG', 4154, 4155],
#  ['AG', 'ORG', 4156, 4157],
#  ['PA-AG', 'ORG', 4212, 4215],
#  ['PD-AG', 'ORG', 4217, 4220],
#  ['Age of Onset', 'ORG', 4222, 4225],
#  ['Cumulative Probability', 'ORG', 4227, 4229],
#  ['APR', 'ORG', 4280, 4281],
#  ['American Medical Association', 'ORG', 4286, 4289],
#  ['PD', 'ORG', 4307, 4308],
#  ['PA', 'ORG', 4341, 4342],
#  ['AG', 'ORG', 4359, 4360],
#  ['PD', 'ORG', 4364, 4365],
#  ['PA-AG', 'ORG', 4370, 4373],
#  ['PD', 'ORG', 4384, 4385],
#  ['PD-AG', 'ORG', 4399, 4402],
#  ['PA-AG', 'ORG', 4423, 4426],
#  ['PD', 'ORG', 4436, 4437],
#  ['PD-AG', 'ORG', 4448, 4451],
#  ['AG', 'ORG', 4476, 4477],
#  ['PD', 'ORG', 4478, 4479],
#  ['CLINICAL', 'ORG', 4494, 4495],
#  ['12-month', 'ORG', 4510, 4511],
#  ['PD-AG', 'ORG', 4530, 4533],
#  ['PA', 'ORG', 4555, 4556],
#  ['Characteristic Odds Ratio', 'ORG', 4593, 4596],
#  ['PA-AG', 'ORG', 4609, 4612],
#  ['PD-AG', 'ORG', 4624, 4627],
#  ['Race Hispanic', 'ORG', 4762, 4764],
#  ['White 1.0', 'ORG', 4838, 4840],
#  ['Education', 'ORG', 4848, 4849],
#  ['Married/cohabitating', 'ORG', 4942, 4945],
#  ['Working 1.0 1.0 1.0 1.0 Student', 'ORG', 5011, 5017],
#  ['Homemaker', 'ORG', 5041, 5042],
#  ['Abbreviations: AG', 'ORG', 5213, 5216],
#  ['PA', 'ORG', 5219, 5220],
#  ['PD', 'ORG', 5224, 5225],
#  ['PA', 'ORG', 5229, 5230],
#  ['PA', 'ORG', 5235, 5236],
#  ['PD or AG', 'ORG', 5238, 5241],
#  ['PA-AG', 'ORG', 5242, 5245],
#  ['PA', 'ORG', 5249, 5250],
#  ['AG', 'ORG', 5251, 5252],
#  ['PD', 'ORG', 5254, 5255],
#  ['PD', 'ORG', 5256, 5257],
#  ['PD', 'ORG', 5262, 5263],
#  ['AG', 'ORG', 5264, 5265],
#  ['PD-AG', 'ORG', 5266, 5269],
#  ['PD', 'ORG', 5273, 5274],
#  ['AG', 'ORG', 5275, 5276],
#  ['PA', 'ORG', 5322, 5323],
#  ['PA-AG', 'ORG', 5326, 5329],
#  ['PD', 'ORG', 5331, 5332],
#  ['104 PD-AG', 'ORG', 5335, 5339],
#  ['REPRINTED) ARCH GEN PSYCHIATRY/VOL 63', 'ORG', 5364, 5372],
#  ['APR', 'ORG', 5373, 5374],
#  ['American Medical Association', 'ORG', 5379, 5382],
#  ['PA-AG', 'ORG', 5397, 5400],
#  ['PD', 'ORG', 5425, 5426],
#  ['Summary SDS', 'ORG', 5446, 5448],
#  ['the PD-AG', 'ORG', 5461, 5465],
#  ['PA', 'ORG', 5486, 5487],
#  ['PA-AG', 'ORG', 5514, 5517],
#  ['SDS', 'ORG', 5520, 5521],
#  ['PA', 'ORG', 5573, 5574],
#  ['PD', 'ORG', 5597, 5598],
#  ['AG', 'ORG', 5612, 5613],
#  ['the PA-AG', 'ORG', 5634, 5638],
#  ['PA', 'ORG', 5643, 5644],
#  ['PD', 'ORG', 5669, 5670],
#  ['PD-AG', 'ORG', 5680, 5683],
#  ['PA', 'ORG', 5697, 5698],
#  ['PA-AG', 'ORG', 5708, 5711],
#  ['PA-AG', 'ORG', 5745, 5748],
#  ['PD-AG', 'ORG', 5794, 5797],
#  ['PA', 'ORG', 5806, 5807],
#  ['the PA-AG', 'ORG', 5818, 5822],
#  ['PD', 'ORG', 5827, 5828],
#  ['12-month', 'ORG', 5844, 5845],
#  ['PD', 'ORG', 5859, 5860],
#  ['PD-AG', 'ORG', 5870, 5873],
#  ['PA', 'ORG', 5884, 5885],
#  ['PA-AG', 'ORG', 5895, 5898],
#  ['PA-AG PD', 'ORG', 5948, 5952],
#  ['PD-AG', 'ORG', 5953, 5956],
#  ['Generalized', 'ORG', 5989, 5990],
#  ['Attention-', 'ORG', 6342, 6344],
#  ['NA', 'ORG', 6356, 6357],
#  ['NA', 'ORG', 6365, 6366],
#  ['NA', 'ORG', 6378, 6379],
#  ['NA 7.3 Conduct', 'ORG', 6387, 6390],
#  ['NA', 'ORG', 6399, 6400],
#  ['NA', 'ORG', 6408, 6409],
#  ['NA', 'ORG', 6455, 6456],
#  ['NA', 'ORG', 6464, 6465],
#  ['Alcohol', 'ORG', 6502, 6503],
#  ['NA 83.1 6.5', 'ORG', 6642, 6645],
#  ['NA 5.3 Abbreviations: AG', 'ORG', 6651, 6656],
#  ['NA', 'ORG', 6664, 6665],
#  ['PA', 'ORG', 6674, 6675],
#  ['PD', 'ORG', 6679, 6680],
#  ['PA', 'ORG', 6684, 6685],
#  ['PA', 'ORG', 6690, 6691],
#  ['PD or AG', 'ORG', 6693, 6696],
#  ['PA-AG', 'ORG', 6697, 6700],
#  ['PA', 'ORG', 6704, 6705],
#  ['AG', 'ORG', 6706, 6707],
#  ['PD', 'ORG', 6709, 6710],
#  ['PD', 'ORG', 6711, 6712],
#  ['PD', 'ORG', 6717, 6718],
#  ['AG', 'ORG', 6719, 6720],
#  ['PD-AG', 'ORG', 6721, 6724],
#  ['PD', 'ORG', 6728, 6729],
#  ['AG', 'ORG', 6730, 6731],
#  ['PA-AG', 'ORG', 6825, 6828],
#  ['PD-AG', 'ORG', 6829, 6832],
#  ['REPRINTED', 'ORG', 6834, 6835],
#  ['PSYCHIATRY/VOL 63', 'ORG', 6838, 6842],
#  ['APR 2006', 'ORG', 6843, 6845],
#  ['American Medical Association', 'ORG', 6849, 6852],
#  ['PD or AG', 'ORG', 6892, 6895],
#  ['PA', 'ORG', 6916, 6917],
#  ['PD and AG', 'ORG', 6930, 6933],
#  ['COMMENT', 'ORG', 6939, 6940],
#  ['SCID PD', 'ORG', 7045, 7047],
#  ['PA or AG', 'ORG', 7057, 7060],
#  ['AOO', 'ORG', 7067, 7068],
#  ['NCS-R', 'ORG', 7096, 7099],
#  ['AOO', 'ORG', 7114, 7115],
#  ['NCS', 'ORG', 7137, 7138],
#  ['DSM-IV PD', 'ORG', 7144, 7148],
#  ['PD-AG', 'ORG', 7149, 7152],
#  ['NCS', 'ORG', 7174, 7175],
#  ['NCS', 'ORG', 7186, 7187],
#  ['PD', 'ORG', 7191, 7192],
#  ['NCS', 'ORG', 7205, 7206],
#  ['NCS-R PD', 'ORG', 7219, 7223],
#  ['AG', 'ORG', 7239, 7240],
#  ['CIDI', 'ORG', 7252, 7253],
#  ['the DSM-IV', 'ORG', 7262, 7266],
#  ['NCS', 'ORG', 7365, 7366],
#  ['the DSM-IV', 'ORG', 7382, 7386],
#  ['CIDI', 'ORG', 7389, 7390],
#  ['NCS', 'ORG', 7407, 7408],
#  ['PD', 'ORG', 7430, 7431],
#  ['AG', 'ORG', 7434, 7435],
#  ['DSM-IV', 'ORG', 7454, 7457],
#  ['PD', 'ORG', 7476, 7477],
#  ['PD', 'ORG', 7512, 7513],
#  ['cues,38,39', 'ORG', 7527, 7528],
#  ['NCS', 'ORG', 7532, 7533],
#  ['PD', 'ORG', 7562, 7563],
#  ['AG', 'ORG', 7565, 7566],
#  ['AG', 'ORG', 7581, 7582],
#  ['PD', 'ORG', 7584, 7585],
#  ['AG', 'ORG', 7602, 7603],
#  ['AG', 'ORG', 7609, 7610],
#  ['PD', 'ORG', 7611, 7612],
#  ['PA and AG', 'ORG', 7626, 7629],
#  ['PD', 'ORG', 7633, 7634],
#  ['PA-AG', 'ORG', 7680, 7683],
#  ['PD-AG', 'ORG', 7697, 7700],
#  ['AG', 'ORG', 7849, 7850],
#  ['NA', 'ORG', 7853, 7854],
#  ['PA', 'ORG', 7858, 7859],
#  ['PD', 'ORG', 7863, 7864],
#  ['PA', 'ORG', 7868, 7869],
#  ['PA', 'ORG', 7874, 7875],
#  ['PD or AG', 'ORG', 7877, 7880],
#  ['PA-AG', 'ORG', 7881, 7884],
#  ['PA', 'ORG', 7888, 7889],
#  ['AG', 'ORG', 7890, 7891],
#  ['PD', 'ORG', 7893, 7894],
#  ['PD', 'ORG', 7895, 7896],
#  ['PD', 'ORG', 7901, 7902],
#  ['AG', 'ORG', 7903, 7904],
#  ['PD-AG', 'ORG', 7905, 7908],
#  ['PD', 'ORG', 7912, 7913],
#  ['AG', 'ORG', 7914, 7915],
#  ['12-month', 'ORG', 7926, 7927],
#  ['12-month', 'ORG', 7942, 7943],
#  ['Panic Disorder Severity Scale', 'ORG', 7970, 7974],
#  ['PSYCHIATRY/VOL 63', 'ORG', 8099, 8103],
#  ['APR 2006', 'ORG', 8104, 8106],
#  ['WWW.ARCHGENPSYCHIATRY.COM', 'ORG', 8106, 8107],
#  ['American Medical Association', 'ORG', 8110, 8113],
#  ['AG', 'ORG', 8127, 8128],
#  ['PA-AG40', 'ORG', 8136, 8139],
#  ['PD-AG', 'ORG', 8144, 8147],
#  ['PD', 'ORG', 8151, 8152],
#  ['AG', 'ORG', 8159, 8160],
#  ['PD', 'ORG', 8161, 8162],
#  ['AG', 'ORG', 8182, 8183],
#  ['PD', 'ORG', 8186, 8187],
#  ['PA', 'ORG', 8188, 8189],
#  ['AG', 'ORG', 8196, 8197],
#  ['PD', 'ORG', 8198, 8199],
#  ['PA', 'ORG', 8212, 8213],
#  ['PD-AG', 'ORG', 8215, 8218],
#  ['PA-AG', 'ORG', 8239, 8242],
#  ['PD', 'ORG', 8243, 8244],
#  ['AG', 'ORG', 8255, 8256],
#  ['PA', 'ORG', 8259, 8260],
#  ['PA', 'ORG', 8276, 8277],
#  ['PD', 'ORG', 8278, 8279],
#  ['PA', 'ORG', 8324, 8325],
#  ['PD', 'ORG', 8327, 8328],
#  ['PA', 'ORG', 8375, 8376],
#  ['PD', 'ORG', 8377, 8378],
#  ['PA', 'ORG', 8388, 8389],
#  ['PA', 'ORG', 8396, 8397],
#  ['researchmightprofitablyattempttostudyPAonlyandevaluate', 'ORG', 8400, 8401],
#  ['PD', 'ORG', 8408, 8409],
#  ['NCS-R', 'ORG', 8426, 8429],
#  ['PDSS', 'ORG', 8439, 8440],
#  ['PD-AG', 'ORG', 8457, 8460],
#  ['PA-AG', 'ORG', 8469, 8472],
#  ['PD', 'ORG', 8473, 8474],
#  ['PDSS', 'ORG', 8483, 8484],
#  ['PDSS', 'ORG', 8495, 8496],
#  ['SDS', 'ORG', 8502, 8503],
#  ['AG (PA-AG', 'ORG', 8511, 8516],
#  ['PD', 'ORG', 8522, 8523],
#  ['PD', 'ORG', 8524, 8525],
#  ['PA', 'ORG', 8527, 8528],
#  ['AG', 'ORG', 8539, 8540],
#  ['AG', 'ORG', 8560, 8561],
#  ['PD', 'ORG', 8567, 8568],
#  ['PA', 'ORG', 8569, 8570],
#  ['AG', 'ORG', 8590, 8591],
#  ['PA', 'ORG', 8594, 8595],
#  ['PD', 'ORG', 8596, 8597],
#  ['AG', 'ORG', 8607, 8608],
#  ['AG', 'ORG', 8629, 8630],
#  ['PD', 'ORG', 8633, 8634],
#  ['AG', 'ORG', 8640, 8641],
#  ['NCS-R', 'ORG', 8655, 8658],
#  ['PD', 'ORG', 8663, 8664],
#  ['PD and/or AG', 'ORG', 8688, 8691],
#  ['Lifetime', 'ORG', 8791, 8792],
#  ['PA-AG', 'ORG', 8814, 8817],
#  ['PD-AG', 'ORG', 8819, 8822],
#  ['Human', 'ORG', 9059, 9060],
#  ['Guideline', 'ORG', 9138, 9139],
#  ['AG', 'ORG', 9161, 9162],
#  ['PA', 'ORG', 9165, 9166],
#  ['PD', 'ORG', 9170, 9171],
#  ['PA', 'ORG', 9175, 9176],
#  ['PA', 'ORG', 9181, 9182],
#  ['PD or AG', 'ORG', 9184, 9187],
#  ['PA-AG', 'ORG', 9188, 9191],
#  ['PA', 'ORG', 9195, 9196],
#  ['AG', 'ORG', 9197, 9198],
#  ['PD', 'ORG', 9200, 9201],
#  ['PD', 'ORG', 9202, 9203],
#  ['PD', 'ORG', 9208, 9209],
#  ['AG', 'ORG', 9210, 9211],
#  ['PD-AG', 'ORG', 9212, 9215],
#  ['PD', 'ORG', 9219, 9220],
#  ['AG', 'ORG', 9221, 9222],
#  ['REPRINTED) ARCH GEN PSYCHIATRY/VOL 63', 'ORG', 9252, 9260],
#  ['APR', 'ORG', 9261, 9262],
#  ['American Medical Association', 'ORG', 9267, 9270],
#  ['Submitted for Publication', 'ORG', 9308, 9311],
#  ['Department of Health Care Policy', 'ORG', 9339, 9344],
#  ['Harvard Medical School', 'ORG', 9345, 9348],
#  ['Longwood Ave', 'ORG', 9350, 9352],
#  ['The National Comorbidity Survey Replication', 'ORG', 9366, 9371],
#  ['NCS-R', 'ORG', 9372, 9375],
#  ['the National Institute of Mental Health', 'ORG', 9382, 9388],
#  ['the National Institute of Drug Abuse', 'ORG', 9396, 9402],
#  ['Substance Abuse', 'ORG', 9407, 9409],
#  ['Mental Health Services Administration', 'ORG', 9410, 9414],
#  ['The Robert Wood Johnson Foundation', 'ORG', 9418, 9423],
#  ['Disclaimer', 'ORG', 9431, 9432],
#  ['Harvard Medical School', 'ORG', 9481, 9484],
#  ['Michigan State University', 'ORG', 9498, 9501],
#  ['The Johns Hopkins University', 'ORG', 9509, 9513],
#  ['Harvard University', 'ORG', 9528, 9530],
#  ['Indiana University', 'ORG', 9539, 9541],
#  ['New York State Psychiatric Institute', 'ORG', 9548, 9553],
#  ['College of Physicians and Surgeons of Columbia University',
#   'ORG',
#   9554,
#   9562],
#  ['University of Pittsburgh', 'ORG', 9570, 9573],
#  ['Group Health Cooperative', 'ORG', 9582, 9585],
#  ['Group Health Cooperative', 'ORG', 9595, 9598],
#  ['Harvard Medical School', 'ORG', 9603, 9606],
#  ['University of California', 'ORG', 9611, 9614],
#  ['Cornell University', 'ORG', 9622, 9624],
#  ['NY', 'ORG', 9627, 9628],
#  ['HansUlrich Wittchen', 'ORG', 9631, 9633],
#  ['Max Planck Institute of Psychiatry', 'ORG', 9634, 9639],
#  ['Institute of Psychology, Technical University Dresden', 'ORG', 9645, 9652],
#  ['NCS', 'ORG', 9662, 9663],
#  ['NCS-R', 'ORG', 9670, 9673],
#  ['NCS-R', 'ORG', 9689, 9692],
#  ['the World Health Organization World Mental Health (WMH) Survey Initiative',
#   'ORG',
#   9697,
#   9709],
#  ['R01', 'ORG', 9716, 9717],
#  ['Catherine T. MacArthur Foundation', 'ORG', 9725, 9729],
#  ['the Pfizer Foundation', 'ORG', 9730, 9733],
#  ['the US Public Health Service', 'ORG', 9742, 9747],
#  ['the Pan American Health Organization', 'ORG', 9757, 9762],
#  ['Eli Lilly and Company', 'ORG', 9763, 9767],
#  ['Ortho-McNeil Pharmaceutical, Inc', 'ORG', 9768, 9774],
#  ['GlaxoSmithKline', 'ORG', 9775, 9776],
#  ['Bristol-Myers Squibb', 'ORG', 9778, 9782],
#  ['WMH', 'ORG', 9787, 9788],
#  ['the WMH Data Collection', 'ORG', 9803, 9807],
#  ['Data Analysis Coordination Centres', 'ORG', 9808, 9812],
#  ['Kessler RC', 'ORG', 9828, 9830],
#  ['McGonagle KA', 'ORG', 9831, 9833],
#  ['Hughes M', 'ORG', 9840, 9842],
#  ['Kendler KS', 'ORG', 9849, 9851],
#  ['Lifetime', 'ORG', 9852, 9853],
#  ['DSM-III', 'ORG', 9857, 9860],
#  ['the National Comorbidity Survey', 'ORG', 9871, 9875],
#  ['Magee WJ', 'ORG', 9895, 9897],
#  ['the National Comorbidity Survey', 'ORG', 9934, 9938],
#  ['Burke KC', 'ORG', 9949, 9951],
#  ['Regier DA', 'ORG', 9956, 9958],
#  ['Kessler RC', 'ORG', 9984, 9986],
#  ['Wetzler S', 'ORG', 9995, 9997],
#  ['Sanderson WC', 'ORG', 9998, 10000],
#  ['Treatment Strategies for Patients With Psychiatric Comorbidity',
#   'ORG',
#   10003,
#   10010],
#  ['John Wiley & Sons', 'ORG', 10016, 10020],
#  ['Stang PE', 'ORG', 10028, 10030],
#  ['HU, Ustun TB', 'ORG', 10032, 10036],
#  ['Walters EE', 'ORG', 10042, 10044],
#  ['Lifetime', 'ORG', 10045, 10046],
#  ['the National Comorbidity Survey', 'ORG', 10051, 10055],
#  ['Stang P', 'ORG', 10071, 10073],
#  ['Walters EE', 'ORG', 10080, 10082],
#  ['Kessler RC', 'ORG', 10083, 10085],
#  ['Lifetime', 'ORG', 10086, 10087],
#  ['the National Comorbidity Survey', 'ORG', 10092, 10096],
#  ['Klerman GL', 'ORG', 10121, 10123],
#  ['Ouellette R', 'ORG', 10127, 10129],
#  ['Johnson J', 'ORG', 10130, 10132],
#  ['JAMA', 'ORG', 10148, 10149],
#  ['Markowitz JS', 'ORG', 10158, 10160],
#  ['Ouellette R', 'ORG', 10164, 10166],
#  ['DSM-IV', 'ORG', 10246, 10249],
#  ['Katschnig H,', 'ORG', 10280, 10283],
#  ['Eaton WW', 'ORG', 10305, 10307],
#  ['Tien A', 'ORG', 10314, 10316],
#  ['Onset', 'ORG', 10335, 10336],
#  ['the Baltimore Epidemiologic Catchment Area', 'ORG', 10342, 10347],
#  ['Heeringa S', 'ORG', 10373, 10375],
#  ['NCS-R', 'ORG', 10400, 10403],
#  ['Ustun TB', 'ORG', 10427, 10429],
#  ['The World Mental Health (WMH) Survey Initiative Version of the World Health Organization (WHO)',
#   'ORG',
#   10430,
#   10448],
#  ['Composite International Diagnostic Interview', 'ORG', 10448, 10452],
#  ['Abelson J', 'ORG', 10471, 10473],
#  ['Escobar JI', 'ORG', 10477, 10479],
#  ['Vega WA', 'ORG', 10492, 10494],
#  ['Walters EE', 'ORG', 10495, 10497],
#  ['DSM-IV', 'ORG', 10509, 10512],
#  ['the World Mental Health (WMH', 'ORG', 10514, 10520],
#  ['the World Health Organization', 'ORG', 10523, 10527],
#  ['Composite International Diagnostic Interview', 'ORG', 10530, 10534],
#  ['Kessler RC', 'ORG', 10550, 10552],
#  ['Walters EE', 'ORG', 10562, 10564],
#  ['Lifetime', 'ORG', 10565, 10566],
#  ['DSM-IV', 'ORG', 10575, 10578],
#  ['the National Comorbidity Survey Replication', 'ORG', 10580, 10585],
#  ['First MB', 'ORG', 10596, 10598],
#  ['Structured Clinical Interview for DSM-IV Axis', 'ORG', 10608, 10616],
#  ['Research Version', 'ORG', 10619, 10621],
#  ['New York State Psychiatric Institute', 'ORG', 10640, 10645],
#  ['Shear MK', 'ORG', 10650, 10652],
#  ['Houck P', 'ORG', 10669, 10671],
#  ['Spiegel DA', 'ORG', 10701, 10703],
#  ['Shear MK', 'ORG', 10704, 10706],
#  ['Depress Anxiety', 'ORG', 10723, 10725],
#  ['Olfson M', 'ORG', 10735, 10737],
#  ['Portera L', 'ORG', 10738, 10740],
#  ['Farber L', 'ORG', 10741, 10743],
#  ['Kessler RC', 'ORG', 10785, 10787],
#  ['the National Comorbidity Survey Replication', 'ORG', 10802, 10807],
#  ['American Psychiatric Association', 'ORG', 10818, 10821],
#  ['Practice Guideline', 'ORG', 10822, 10824],
#  ['the Treatment of Patients With Panic Disorder', 'ORG', 10825, 10832],
#  ['American Psychiatric Association Press', 'ORG', 10837, 10841],
#  ['Textbook of Psychopharmacology', 'ORG', 10854, 10857],
#  ['American Psychiatric Publishing', 'ORG', 10862, 10865],
#  ['REPRINTED) ARCH GEN PSYCHIATRY/VOL 63', 'ORG', 10869, 10877],
#  ['APR', 'ORG', 10878, 10879],
#  ['American Medical Association', 'ORG', 10884, 10887],
#  ['Halli SS', 'ORG', 10901, 10903],
#  ['Halli SS', 'ORG', 10907, 10909],
#  ['Advanced Techniques of Population Analysis', 'ORG', 10910, 10915],
#  ['NY:', 'ORG', 10919, 10921],
#  ['Plenum Publishing Corp', 'ORG', 10921, 10924],
#  ['DW', 'ORG', 10930, 10931],
#  ['Lemeshow S. Applied Logistic Regression', 'ORG', 10932, 10937],
#  ['John Wiley & Sons', 'ORG', 10946, 10950],
#  ['Springer-Verlag NY Inc', 'ORG', 10968, 10973],
#  ['SUDAAN', 'ORG', 10978, 10979],
#  ['Professional Software for Survey Data Analysis', 'ORG', 10980, 10986],
#  ['Version 8.0.1', 'ORG', 10987, 10989],
#  ['Research Triangle Institute', 'ORG', 10996, 10999],
#  ['Cannell CF', 'ORG', 11008, 11010],
#  ['Schwarz N', 'ORG', 11011, 11013],
#  ['Kessler RC', 'ORG', 11017, 11019],
#  ['the US National Comorbidity Survey', 'ORG', 11031, 11036],
#  ['Canino GJ', 'ORG', 11055, 11057],
#  ['Hwu HG', 'ORG', 11064, 11066],
#  ['Lee CK', 'ORG', 11073, 11075],
#  ['Lellouch J', 'ORG', 11076, 11078],
#  ['Oakley-Browne MA', 'ORG', 11085, 11089],
#  ['RubioStipec M', 'ORG', 11090, 11092],
#  ['Wells JE', 'ORG', 11093, 11095],
#  ['Kessler RC', 'ORG', 11124, 11126],
#  ['Psychiatric', 'ORG', 11147, 11148],
#  ['John Wiley & Sons', 'ORG', 11155, 11159],
#  ['JA', 'ORG', 11170, 11171],
#  ['Oakley-Browne MA', 'ORG', 11172, 11176],
#  ['Wells JE', 'ORG', 11177, 11179],
#  ['Hornblow AR', 'ORG', 11180, 11182],
#  ['Muller N', 'ORG', 11216, 11218],
#  ['the German Health Interview and Examination Survey', 'ORG', 11238, 11245],
#  ['GHS', 'ORG', 11246, 11247],
#  ['Bruffaerts R', 'ORG', 11267, 11269],
#  ['Bryson H', 'ORG', 11273, 11275],
#  ['de Girolamo G', 'ORG', 11276, 11279],
#  ['Gasquet I', 'ORG', 11286, 11288],
#  ['Kessler RC', 'ORG', 11295, 11297],
#  ['Kovess V', 'ORG', 11298, 11300],
#  ['Ormel J', 'ORG', 11304, 11306],
#  ['Autonell J', 'ORG', 11324, 11326],
#  ['Bernal M', 'ORG', 11327, 11329],
#  ['Buist-Bouwman MA', 'ORG', 11330, 11334],
#  ['Joo SS', 'ORG', 11346, 11348],
#  ['Matschinger H', 'ORG', 11354, 11356],
#  ['Morgan Z', 'ORG', 11360, 11362],
#  ['Taub N', 'ORG', 11372, 11374],
#  ['Vollebergh WA', 'ORG', 11375, 11377],
#  ['European Study of the Epidemiology of Mental Disorders',
#   'ORG',
#   11384,
#   11392],
#  ['the European Study of the Epidemiology of Mental Disorders (',
#   'ORG',
#   11408,
#   11418],
#  ['Barlow DH', 'ORG', 11433, 11435],
#  ['Phobic', 'ORG', 11470, 11471],
#  ['Cognitive-Behavioral Therapy', 'ORG', 11518, 11522],
#  ['Sage Publications', 'ORG', 11531, 11533],
#  ['White KS', 'ORG', 11540, 11542],
#  ['Barlow DH', 'ORG', 11543, 11545],
#  ['Barlow DH', 'ORG', 11553, 11555],
#  ['Treatment of Anxiety and Panic', 'ORG', 11566, 11571],
#  ['Guilford Publications', 'ORG', 11580, 11582],
#  ['Crowe RR', 'ORG', 11589, 11591],
#  ['Murrell E. Predictors', 'ORG', 11620, 11623],
#  ['Norton GR', 'ORG', 11662, 11664],
#  ['Panic Disorder', 'ORG', 11670, 11672],
#  ['Practitioner', 'ORG', 11680, 11681],
#  ['Norton GR', 'ORG', 11695, 11697],
#  ['Harrison B', 'ORG', 11698, 11700],
#  ['Norton GR', 'ORG', 11724, 11726],
#  ['Dorward J', 'ORG', 11727, 11729],
#  ['Bouton ME', 'ORG', 11751, 11753],
#  ['Mineka S', 'ORG', 11754, 11756],
#  ['Clark DM', 'ORG', 11780, 11782],
#  ['Barlow DH', 'ORG', 11802, 11804],
#  ['Telch MJ', 'ORG', 11824, 11826],
#  ['Fabisch H', 'ORG', 11871, 11873],
#  ['Lane M', 'ORG', 11902, 11904],
#  ['Olfson M', 'ORG', 11905, 11907],
#  ['Kessler RC', 'ORG', 11914, 11916],
#  ['the National Comorbidity Survey Replication', 'ORG', 11932, 11937],
#  ['Deveney C. Cognitive', 'ORG', 11951, 11954],
#  ['Busch F', 'ORG', 12028, 12030],
#  ['Roiphe J', 'ORG', 12037, 12039],
#  ['Singer M', 'ORG', 12043, 12045],
#  ['Goldman H', 'ORG', 12049, 12051],
#  ['Shear MK', 'ORG', 12055, 12057],
#  ['Pollack MH', 'ORG', 12083, 12085],
#  ['REPRINTED) ARCH GEN PSYCHIATRY/VOL 63', 'ORG', 12132, 12140],
#  ['APR', 'ORG', 12141, 12142],
#  ['American Medical Association', 'ORG', 12147, 12150]]

# %%
df['sents'] = [[s for s in i.sents] for i in df.doc]

# %%
df.sents
# Out:
# 0    [(ORIGINAL, ARTICLE), (The, Epidemiology, of, ...
# 1    [(ORIGINAL, ARTICLE, Lifetime, Prevalence, and...
# 2    [(MarketWatch, Medicaid, Cost, Containment, An...
# 3    [(Unmet, Need, for, Personal, Assistance, Serv...
# 4    [(ANNALS, OF, FAMILY, MEDICINE,  , WWW.ANNFAMM...
# Name: sents, dtype: object

# %%
df.head(1)
# Out:
#    filename                                         rawContent  \
# 0  1003.txt  ORIGINAL ARTICLE The Epidemiology of Panic Att...
#
#                                                  doc  \
# 0  (ORIGINAL, ARTICLE, The, Epidemiology, of, Pan...
#
#                                                   NC  \
# 0  [[ORIGINAL ARTICLE, ARTICLE, ROOT, ARTICLE], [...
#
#                                                  NER
# 0  [[Panic Disorder, ORG, 8, 10], [Agoraphobia, G...

# %%
for idx, row in df.iterrows():
    print(len(row.NC), len(row.NER))
    allText = row.rawContent.split(sep=" ")
    for i in row.NER:
        print(allText[i[2]-1:i[3]-1], i[0])
#         allText[i[2]-1:i[3]-1] = ["<NER>"]
#         print(row['doc'][i[2]:i[3]])
#         break
    print(" ".join(allText))
#     print(row['doc'][i[2]:i[3]])
    break
# Out:
# 2443 2209
# 8 10
# ['Panic', 'Disorder,'] Panic Disorder
# 12 13
# ['in'] Agoraphobia
# 14 22
# ['National', 'Comorbidity', 'Survey', 'Replication', 'Ronald', 'C.', 'Kessler,', 'PhD;'] the National Comorbidity Survey Replication Ronald C. Kessler
# 23 24
# ['Tat'] PhD
# 25 28
# ['AM;', 'Robert', 'Jin,'] Wai Tat Chiu
# 31 33
# ['Ruscio,', 'PhD;'] Robert Jin
# 34 35
# ['Shear,'] MA
# 36 39
# ['Ellen', 'E.', 'Walters,'] Ayelet Meron Ruscio
# 40 41
# ['Context:'] PhD
# 42 44
# ['limited', 'information'] Katherine Shear
# 45 46
# ['about'] MD
# 47 50
# ['epidemiology', 'of', 'DSM-IV'] Ellen E. Walters
# 51 53
# ['attacks', '(PAs)'] MS Context
# 62 65
# ['data', 'about', 'the'] DSM-IV
# 74 75
# ['(AG)'] PD
# 90 91
# ['representative'] PD
# 96 97
# ['the'] AG
# 102 108
# ['Composite', 'International', 'Diagnostic', 'Interview.', 'Participants:', 'English-speaking'] the US National Comorbidity Survey Replication
# 126 133
# ['without', 'AG.', 'Results:', 'Lifetime', 'prevalence', 'estimates', 'are'] World Health Organization Composite International Diagnostic Interview
# 136 137
# ['panic'] English
# 143 147
# ['PA', 'with', 'AG', 'without'] 18 years or older
# 158 159
# ['for'] PD
# 162 163
# ['(PD-AG).'] AG
# 166 167
# ['of'] Lifetime
# 170 172
# ['of', 'years'] 22.7%
# 176 179
# ['across', 'these', '4'] AG (PA
# 182 184
# ['subgroups', 'are'] 0.8%
# 185 186
# ['comorbid'] PA
# 187 188
# ['other'] AG
# 189 194
# ['DSM-IV', 'disorders,', 'with', 'the', 'highest'] PD (PA-AG
# 196 198
# ['PD-AG', 'and'] 3.7%
# 199 200
# ['lowest'] PD
# 201 202
# ['PA'] AG
# 203 204
# ['Scores'] PD
# 208 210
# ['Severity', 'Scale'] 1.1%
# 211 218
# ['also', 'highest', 'for', 'PD-AG', '(86.3%', 'moderate', 'or'] PD with AG (PD-AG
# 220 221
# ['lowest'] Persistence
# 230 231
# ['associated'] years
# 237 238
# ['Lifetime'] 4
# 241 242
# ['(from'] 4
# 249 252
# ['only),', 'but', '12-month'] DSM-IV
# 259 262
# ['(from', '54.9%', 'for'] PD-AG
# 266 267
# ['PA'] PA
# 271 276
# ['major', 'societal', 'burden', 'of', 'panic'] the Panic Disorder Severity Scale
# 280 283
# ['and', 'PA-AG,', 'isolated'] PD-AG
# 284 286
# ['also', 'have'] 86.3%
# 293 294
# ['Gen'] PA
# 296 298
# ['EPIDEMIOLOGICAL', 'SURVEY'] 6.7%
# 303 304
# ['of'] Agoraphobia
# 315 316
# ['with'] Lifetime
# 321 323
# ['Despite', 'these'] 96.1%
# 324 327
# ['important', 'questions', 'remain'] PD-AG
# 328 330
# ['about', 'the'] 61.1%
# 331 332
# ['of'] PA
# 336 337
# ['important'] 12-month
# 346 348
# ['isolated', 'panic'] 54.9%
# 349 352
# ['(PAs)', 'that', 'do'] PD-AG
# 353 355
# ['meet', 'criteria'] 18.2%
# 356 357
# ['panic'] PA
# 372 373
# ['use'] PD
# 374 377
# ['psychotropic', 'medication,', 'and'] PA-AG
# 389 392
# ['led', 'to', 'the'] Arch Gen Psychiatry
# 393 394
# ['that'] 2006;63:415
# 412 413
# ['It'] 3
# 419 422
# ['persistent', 'course', 'and'] disorders,5-7
# 466 467
# ['community'] PD
# 497 498
# ['English-speaking'] Axis
# 543 544
# ['and'] AG
# 553 554
# ['Shear).'] AG
# 562 563
# ['415'] PA
# 564 565
# ['American'] PD
# 570 571
# ['Downloaded'] AG
# 602 607
# ['NCS-R', 'recruitment', 'and', 'consent', 'procedures.'] US National Comorbidity Survey Replication
# 608 611
# ['were', 'interviewed', 'in'] NCS-R
# 616 619
# ['interview,', 'administered', 'to'] NCS-R
# 625 626
# ['assessment.'] 9282
# 626 627
# ['The'] English
# 641 644
# ['lifetime', 'core', 'disorder'] between February 2001
# 645 647
# ['a', 'probability'] April 2003
# 652 654
# ['total', 'of'] 70.9%
# 655 656
# ['part'] Consent
# 662 667
# ['correlates', 'and', 'disorders', 'of', 'secondary'] Department of Health Care Policy
# 668 671
# ['The', 'part', '1'] Harvard Medical School
# 672 673
# ['is'] Boston
# 674 675
# ['here'] Mass
# 676 678
# ['examine', 'prevalence'] Drs Kessler
# 679 680
# ['course,'] Ruscio
# 681 683
# ['severity', 'and'] Messrs Chiu
# 684 685
# ['impairment,'] Jin
# 687 689
# ['aspects', 'of'] Ms Walters
# 692 696
# ['2', 'sample', 'is', 'used'] the Western Psychiatric Institute
# 699 700
# ['with'] Pittsburgh
# 708 716
# ['correlates,', 'and', 'treatment.', 'The', 'part', '1', 'sample', 'was'] REPRINTED) ARCH GEN PSYCHIATRY/VOL 63
# 717 718
# ['to'] APR
# 720 721
# ['differential'] 415
# 722 723
# ['of'] 2006
# 723 726
# ['selection', 'and', 'discrepancies'] American Medical Association
# 744 745
# ['weighted'] NCS
# 752 757
# ['selection', 'from', 'the', 'part', '1'] Harvard Medical School (Boston
# 758 759
# ['More'] Mass
# 761 765
# ['NCS-R', 'sampling', 'and', 'weights'] the University of Michigan
# 766 768
# ['reported', 'elsewhere.15'] Ann Arbor
# 771 774
# ['Panic', 'and', 'AG'] NCS-R
# 783 784
# ['version'] 2
# 788 789
# ['Organization'] 1
# 804 805
# ['assessment'] 2
# 811 812
# ['in'] 1
# 832 833
# ['blue"'] 5692
# 834 835
# ['no'] 2
# 851 852
# ['2'] 1
# 876 877
# ['medical'] 2
# 886 887
# ['concern'] secondary
# 900 901
# ['behavior'] 1
# 918 919
# ['include'] US
# 929 930
# ['or'] 2
# 944 945
# ['that'] 1
# 950 953
# ['embarrassing', 'to', 'escape.'] NCS-R
# 961 963
# ['the', 'feared'] AG Panic
# 964 965
# ['distress'] AG
# 968 974
# ['these', 'situations,', 'or', 'the', 'necessity', 'of'] the World Mental Health Survey Initiatiave
# 976 984
# ['during', 'these', 'situations.', 'We', 'used', 'these', 'classifications', 'to'] the World Health Organization Composite International Diagnostic Interview
# 1013 1014
# ['The'] CIDI
# 1067 1068
# ['elsewhere,17,18'] 4
# 1084 1086
# ['(SCID)19', 'were'] 1 month
# 1112 1113
# ['receiver'] Agoraphobia
# 1118 1119
# ['a'] 2
# 1151 1152
# ['in'] PA
# 1199 1200
# ['analysis'] 4
# 1205 1206
# ['recurrent'] PA
# 1207 1208
# ['PAs,'] PD
# 1209 1212
# ['could', 'be', 'interpreted'] AG (PA
# 1215 1216
# ['more,'] PA
# 1217 1224
# ['a', 'PD', 'diagnosis.', 'However,', 'CIDI', 'respondents', 'who'] PD and AG (PA-AG
# 1226 1227
# ['or'] PD
# 1228 1229
# ['lifetime'] AG
# 1230 1231
# ['PAs'] PD
# 1235 1236
# ['the'] PD
# 1237 1238
# ['to'] AG
# 1239 1242
# ['had', 'only', '1'] PD-AG
# 1245 1246
# ['additional'] PA
# 1253 1254
# ['relation'] DSM
# 1258 1261
# ['was', 'improved', 'when'] PA-AG
# 1265 1269
# ['4', 'lifetime', 'uncued', 'attacks'] the DSM-IV
# 1270 1271
# ['the'] AG
# 1275 1276
# ['result'] PD
# 1280 1281
# ['PD'] AG
# 1285 1286
# ['differ'] PA
# 1321 1329
# ['first', 'attack', 'and', 'AOO', 'of', 'having', '4', 'uncued'] the Structured Clinical Interview for DSM-IV
# 1330 1331
# ['with'] SCID)19
# 1338 1339
# ['were'] 325
# 1339 1340
# ['asked'] NCS
# 1356 1357
# ['and'] PD
# 1368 1369
# ['assessed'] 0.72
# 1379 1380
# ['of'] 0.45
# 1381 1382
# ['7-question'] 0.15
# 1393 1394
# ['NCS-R.'] 56.3
# 1395 1397
# ['wording', 'is'] 95%
# 1400 1401
# ['The'] 15.5
# 1411 1412
# ['assessment'] CIDI
# 1423 1424
# ['the'] McNemar
# 1426 1428
# ['independently', 'of'] 2 1
# 1429 1430
# ['NCS-R'] 0
# 1443 1444
# ['PDSS'] PA
# 1445 1446
# ['points'] PA
# 1460 1461
# ['7'] AG
# 1462 1463
# ['questions'] AG
# 1477 1481
# ['(SDS),22', 'also', 'was', 'included'] The DSM-IV
# 1491 1492
# ['with'] 2
# 1497 1498
# ['the'] PD
# 1502 1503
# ['past'] CIDI
# 1506 1509
# ['panic,', 'their', 'worry'] 2 or 3
# 1521 1523
# ['worry', 'interfered'] only 1
# 1524 1525
# ['with'] PA
# 1535 1536
# ['a'] CIDI
# 1547 1550
# ['(0),', 'mild', '(1-3),'] at least 4
# 1555 1556
# ['very'] CIDI
# 1558 1559
# ['Interference'] McNemar
# 1564 1565
# ['role'] CIDI
# 1574 1575
# ['Responses'] SCID
# 1580 1582
# ['highest', 'score'] only 2
# 1584 1585
# ['4'] COURSE
# 1589 1591
# ['severe', 'and'] IMPAIRMENT Respondents
# 1593 1596
# ['response', 'categories.', 'COMORBID'] DSM-IV
# 1599 1600
# ['NCS-R'] PA
# 1609 1610
# ['disorders:'] AOO
# 1613 1614
# ['(generalized'] first
# 1616 1617
# ['specific'] AOO
# 1619 1620
# ['phobia,'] 4
# 1623 1625
# ['obsessive-compulsive', 'disorder,'] a month
# 1654 1655
# ['dependence,'] years
# 1656 1659
# ['which', 'abuse', 'and'] at least 1
# 1677 1678
# ['and'] 7-question
# 1690 1696
# ['conduct', 'disorder).', 'Organic', 'exclusion', 'rules', 'and'] the NCS-R. (Question
# 1708 1709
# ['more'] PDSS
# 1717 1718
# ['nonpatient'] PD
# 1727 1728
# ['CIDI'] PDSS
# 1733 1734
# ['mood,'] NCS
# 1772 1773
# ['to'] 2
# 1775 1776
# ['ORs'] 7
# 1804 1805
# ['12-month'] CIDI
# 1807 1808
# ['panic'] SDS
# 1811 1812
# ['the'] 12-month
# 1816 1819
# ['section.', 'Part', '2'] the 1 month
# 1820 1823
# ['additionally', 'were', 'asked'] the past year
# 1832 1833
# ['for'] PA
# 1857 1858
# ['distinguished'] 0
# 1859 1860
# ['5'] 10
# 1874 1875
# ['treatment'] 1
# 1881 1882
# ['asked'] 46
# 1886 1889
# ['of', 'visits;', 'number'] 7-9
# 1895 1896
# ['name,'] 10
# 1898 1899
# ['duration'] Interference
# 1903 1904
# ['No'] 4
# 1929 1930
# ['of'] 4
# 1941 1946
# ['(at', 'least', '2', 'months', 'of'] COMORBID DSM-IV DISORDERS
# 1947 1950
# ['appropriate', 'medication,', 'defined'] NCS-R
# 1958 1961
# ['visits', 'to', 'any'] DSM-IV
# 2056 2057
# ['course'] 3
# 2080 2081
# ['treatment'] Organic
# 2116 2117
# ['used'] CIDI
# 2128 2129
# ['was'] dis(REPRINTED
# 2137 2138
# ['comorbid'] APR
# 2140 2141
# ['Because'] 416
# 2142 2143
# ['NCS-R'] 2006
# 2143 2146
# ['sample', 'design', 'featured'] American Medical Association
# 2165 2166
# ['of'] 0.65
# 2167 2168
# ['of'] 0.81
# 2169 2170
# ['in']
# 2174 2175
# ['were'] 0.33
# 2176 2177
# ['using'] 0.70
# 2184 2185
# ['variance-covariance'] 6.3
# 2186 2187
# ['Statistical'] 877.0
# 2207 2208
# ['for'] Two
# 2212 2213
# ['(0.5)'] 12-month
# 2227 2228
# ['lifetime'] 2
# 2265 2267
# ['PA-AG,', 'whereas'] seen.23 Treatment
# 2270 2271
# ['respondents'] 5
# 2293 2296
# ['(0.1)', 'for', '12-month'] the 12 months
# 2339 2340
# ['only'] 12-month
# 2357 2359
# ['of', '31.0'] guidelines.24 Guideline
# 2369 2373
# ['other', 'requirements', 'for', 'a'] at least 2 months
# 2384 2387
# ['subgroups,', 'the', 'exception'] at least 4
# 2398 2401
# ['67.9%', 'in', 'PD-AG'] at least 8
# 2414 2418
# ['cued', 'lifetime', 'attack.', 'Mean'] at least 30 minutes
# 2424 2427
# ['with', 'any', 'varies'] at least 4
# 2437 2440
# ['with', 'a', 'significantly'] at least 4
# 2456 2457
# ['and'] PD
# 2463 2466
# ['P=.03)', 'AG.', 'Agoraphobia'] at least 8
# 2481 2484
# ['(78.2', 'vs', '38.3,'] at least 8
# 2485 2486
# ['P=.02)'] visits.24
# 2509 2512
# ['PAs', '(28.3%)', 'PD'] at least 2
# 2530 2532
# ['disorder', '(PD)'] METHODS Cross
# 2546 2547
# ['PD'] method26
# 2551 2552
# ['history'] AOO
# 2569 2570
# ['history'] analysis27
# 2580 2583
# ['(3.7%)', 'and', 'PD-AG'] DSM-IV
# 2587 2588
# ['than'] NCS
# 2601 2602
# ['PSYCHIATRY/VOL'] Taylor
# 2610 2611
# ['Association.'] SUDAAN
# 2612 2614
# ['rights', 'reserved.'] system.29 Significance
# 2627 2629
# ['such', 'attacks'] Wald 2
# 2646 2647
# ['and'] 2-sided
# 2656 2660
# ['No', 'meaningful', 'difference', 'exists'] Twenty-eight percent
# 2665 2667
# ['among', 'the'] 28.3%
# 2668 2669
# ['subgroups'] 1.0
# 2677 2678
# ['distribution'] PA
# 2679 2681
# ['similar', 'across'] 11.2%
# 2682 2683
# ['subgroups'] 0.5
# 2686 2687
# ['AOO'] PA
# 2689 2691
# ['is', 'only'] 4.7%
# 2692 2693
# ['1'] 0.3
# 2697 2700
# ['AOO', 'of', 'PA'] roughly one sixth
# 2704 2705
# ['significantly'] PA
# 2710 2711
# ['subgroups'] PD
# 2712 2714
# ['vs', '22.9,'] 2.8%
# 2718 2720
# ['(12month', 'prevalence'] 12-month PD
# 2721 2722
# ['PA'] Eight
# 2722 2723
# ['among'] tenths
# 2724 2726
# ['cases),', 'however,'] 1%
# 2730 2733
# ['in', 'PA', 'only'] roughly 3%
# 2738 2739
# ['3'] PA
# 2744 2747
# ['higher', 'in', 'the'] PA-AG
# 2748 2750
# ['than', 'PA'] 0.4%
# 2751 2752
# ['in'] 0.1
# 2754 2758
# ['of', 'AG', '(57.4%', 'vs'] 12-month PA-AG
# 2760 2762
# ['P.001)', 'and'] 1.1%
# 2763 2764
# ['presence'] 0.1
# 2768 2771
# ['41.1%,', 'z=3.0,', 'P=.002)'] approximately one fifth
# 2775 2776
# ['as'] PD
# 2777 2779
# ['function', 'of'] 60%
# 2783 2786
# ['2', 'PA', 'subgroups'] PA-AG
# 2791 2794
# ['or', 'in', 'the'] PD-AG
# 2795 2797
# ['PD', 'subgroups'] 0.4%
# 2798 2799
# ['vs'] 0.1
# 2801 2805
# ['P=.36).', 'Mean', 'number', 'of'] 12-month PD-AG
# 2806 2809
# ['with', 'attacks', 'also'] COURSE OF ILLNESS
# 2819 2820
# ['same'] 4
# 2825 2826
# ['CORRELATES'] 1
# 2831 2833
# ['variation', 'in'] 22.7%
# 2837 2840
# ['correlates', 'of', 'lifetime'] PA-AG
# 2841 2843
# ['across', 'the'] 0.8%
# 2844 2845
# ['subgroups,'] PD
# 2847 2849
# ['ORs', 'associated'] 3.7%
# 2851 2854
# ['female', 'are', 'noticeably'] PD-AG
# 2855 2857
# ['for', 'the'] 1.1%
# 2864 2865
# ['ORs'] PD
# 2866 2868
# ['with', 'other'] 12.0%
# 2869 2870
# ['status'] PA
# 2872 2874
# ['higher', 'for'] 10.7%
# 2875 2878
# ['AG', 'than', 'non-AG'] PA-AG
# 2889 2890
# ['ages)'] PD
# 2894 2895
# ['nonHispanic'] 31.0
# 2896 2897
# ['have'] 131.4
# 2911 2912
# ['and'] PD
# 2915 2916
# ['have'] 1
# 2921 2922
# ['in'] 3
# 2924 2925
# ['subgroups.'] 4
# 2930 2931
# ['employment'] PD
# 2934 2937
# ['largely', 'of', 'the'] at least 1
# 2938 2939
# ['and'] lifetime
# 2942 2944
# ['odds', 'of'] 67.9%
# 2945 2948
# ['outcomes', 'other', 'than'] PD-AG
# 2949 2951
# ['only,', 'whereas'] 87.6%
# 2952 2955
# ['people', 'have', 'elevated'] PA-AG
# 2960 2962
# ['the', 'other'] 46.8%
# 2963 2964
# ['outcomes.'] PD
# 2970 2971
# ['in'] lifetime
# 2989 2990
# ['quite'] 18.2
# 2991 2992
# ['(in'] P.001
# 3008 3009
# ['odds'] PA
# 3013 3014
# ['lifetime'] 121.8
# 3015 3016
# ['disorders'] 38.3
# 3017 3018
# ['in'] z=6.6
# 3019 3020
# ['survey'] P.001
# 3025 3026
# ['comorbid'] 134.4
# 3027 3028
# ['are'] 78.2
# 3031 3034
# ['of', 'the', 'PA-only'] P=.03) AG
# 3035 3036
# ['1.'] Agoraphobia
# 3050 3051
# ['Subgroups'] PA
# 3052 3054
# ['PA', 'Only'] 78.2 vs
# 3054 3055
# ['(n'] 38.3
# 3058 3059
# ['(n'] P=.02
# 3065 3066
# ['344)'] PD
# 3067 3068
# ['(n'] 134.4
# 3069 3070
# ['105)'] 121.8
# 3071 3072
# ['3'] z=0.53
# 3073 3074
# ['prevalence'] P=.60
# 3084 3085
# ['(0.1)'] PA
# 3087 3089
# ['Lifetime', 'cued'] 22.7%
# 3093 3095
# ['(4.4)', '46.8'] 28.3%
# 3096 3097
# ['67.9'] PD
# 3099 3101
# ['4', 'Lifetime'] 3.7%
# 3102 3105
# ['attacks', '12.0', '(1.1)'] PD-AG
# 3106 3108
# ['(4.1)', '100.0'] 1.1%
# 3109 3112
# ['100.0', '(0)', '0.1'] PA-AG
# 3113 3115
# ['Age', 'of'] 0.8%
# 3117 3118
# ['PA'] 1
# 3119 3120
# ['(0.5)'] Lifetime
# 3123 3126
# ['(0.8)', '21.5', '(1.0)'] DSM-IV
# 3135 3136
# ['0.5'] PD
# 3142 3143
# ['17.0'] AG
# 3151 3152
# ['persistence*'] PA
# 3154 3157
# ['41.1', '(5.5)', '57.4'] PD or AG
# 3158 3161
# ['62.6', '(4.4)', '48.7'] PA-AG
# 3165 3166
# ['4.7'] PA
# 3167 3168
# ['6.6'] AG
# 3170 3171
# ['(0.6)'] PD
# 3172 3173
# ['(1.1)'] PD
# 3178 3179
# ['38.3'] PD
# 3180 3181
# ['78.2'] AG
# 3182 3185
# ['121.8', '(11.9)', '134.4'] PD-AG
# 3189 3190
# ['uncued'] PD
# 3191 3192
# ['31.0'] AG
# 3197 3198
# ['46.0'] PD
# 3200 3202
# ['Median', '1'] 3.7%
# 3204 3207
# ['attacks', '6.0', '(0.3)'] PD-AG
# 3208 3210
# ['(2.2)', '17.2'] 1.1%
# 3217 3219
# ['uncued', 'attacks'] 4.7%
# 3222 3223
# ['(48.3)'] PD
# 3237 3238
# ['PD,'] APR
# 3240 3242
# ['PA', 'only,'] 417 ©
# 3242 3243
# ['lifetime'] 2006
# 3243 3246
# ['history', 'of', 'PA'] American Medical Association
# 3257 3258
# ['with']
# 3279 3280
# ['are'] PD
# 3284 3285
# ['error).'] 121.8
# 3286 3287
# ['are'] 31.3
# 3290 3291
# ['(standard'] P.001
# 3294 3298
# ['indicated.', '', 'Significant', 'at'] the PD-AG
# 3300 3301
# ['test.'] 134.4
# 3306 3307
# ['30'] P.001
# 3315 3318
# ['30', '50', '70'] AOO of PA
# 3320 3321
# ['60'] 4
# 3323 3326
# ['PA-AG', 'PD', 'Only'] 21.5-22.7
# 3329 3330
# ['Age'] 0.9
# 3331 3332
# ['Onset,'] P=.44
# 3336 3338
# ['Lifetime', 'Prevalence'] PA AOO
# 3346 3347
# ['panic'] 2
# 3352 3353
# ['lifetime'] PD
# 3354 3359
# ['subgroups', '(2', '3', '=6.9,', 'P=.07).'] only about 1 year later
# 3361 3364
# ['to', 'Figure', '1'] AOO of PA
# 3371 3372
# ['GEN'] PD
# 3375 3378
# ['2006', 'WWW.ARCHGENPSYCHIATRY.COM', '418'] PD-AG
# 3380 3381
# ['Medical'] 23.6
# 3382 3383
# ['All'] 22.9
# 3386 3387
# ['From:'] 0.5
# 3393 3394
# ['the'] 12month
# 3396 3397
# ['and'] PA
# 3408 3410
# ['conditions', 'differ'] 35.7%
# 3411 3412
# ['across'] PA
# 3414 3416
# ['subgroups,', 'with'] 62.6%
# 3417 3420
# ['lowest', 'ORs', 'consistently'] PD-AG
# 3421 3422
# ['the'] 2
# 3422 3423
# ['PA-only'] 3
# 3424 3425
# ['In'] 48.7
# 3426 3427
# ['case'] P.001
# 3435 3436
# ['depression,'] PD
# 3443 3444
# ['shown'] AG
# 3445 3447
# ['the', 'PA-AG'] 57.4%
# 3448 3450
# ['(4.4-24.0)', 'consistently'] 35.7%
# 3453 3454
# ['the'] P.001
# 3459 3460
# ['as'] AG
# 3461 3463
# ['as', 'the'] 62.6%
# 3464 3466
# ['ORs', '(2.5-25.8).'] 41.1%
# 3467 3468
# ['the'] z=3.0
# 3479 3480
# ['PA-AG'] AG
# 3483 3484
# ['comparable'] 2
# 3487 3489
# ['ORs', '(3.5-5.4),'] 41.1%
# 3490 3492
# ['the', 'PD-AG'] 35.7%
# 3500 3501
# ['for'] 2
# 3504 3506
# ['for', 'the'] 62.6%
# 3507 3509
# ['is', 'associated'] 57.4%
# 3518 3519
# ['comparable'] years
# 3530 3531
# ['ratings'] 46.7
# 3532 3533
# ['clinical'] P.001
# 3561 3562
# ['42.4%'] 4
# 3576 3577
# ['severe'] PD
# 3579 3580
# ['0.3%'] PA
# 3595 3596
# ['Subgroups*'] AG
# 3606 3612
# ['5172)', 'PA-AG', '(n', '=', '3572)', 'PD'] Age of 60 years or older
# 3620 3621
# ['Age,'] Hispanic
# 3634 3635
# ['1.7'] 4
# 3656 3657
# ['4.0'] 4
# 3659 3660
# ['Sex'] Respondents
# 3684 3685
# ['(0.3-3.2)'] PA
# 3694 3697
# ['0.4', '(0.3-0.6)', '0.5'] PD-AG
# 3701 3702
# ['2.1'] 3
# 3720 3721
# ['1.0'] Pearson
# 3738 3741
# ['1.2', '(0.8-1.9)', '0.8'] 0.01 to 0.02
# 3747 3748
# ['0.8'] 4
# 3759 3762
# ['1.0', '1.0', '1.0'] DSM-IV
# 3769 3770
# ['(1.2-2.1)'] 3
# 3772 3773
# ['Never'] One
# 3780 3782
# ['0.9', '(0.4-2.0)'] 71.9%
# 3784 3785
# ['6.3'] PA
# 3787 3789
# ['Employment', 'status'] Table 1
# 3792 3793
# ['1.0'] Persistence
# 3795 3798
# ['0.8', '(0.5-1.4)', '0.8'] Course of Panic
# 3813 3814
# ['1.0'] 1672
# 3815 3818
# ['1.2', '(0.2-6.6)', '1.0'] PA-AG
# 3821 3822
# ['Other'] 71
# 3828 3829
# ['3.8'] 344
# 3830 3833
# ['2', '1.7', '18.4'] PD-AG
# 3836 3837
# ['family'] 105
# 3838 3840
# ['Low', '1.2'] 2 3
# 3840 3841
# ['(0.9-1.6)'] Lifetime
# 3846 3847
# ['(0.6-3.2)'] 22.7
# 3848 3849
# ['1.0'] 1.0
# 3850 3851
# ['0.9'] 0.8
# 3852 3853
# ['1.4'] 0.1
# 3856 3857
# ['High-average'] 0.2
# 3858 3859
# ['(1.0-1.4)'] 1.1
# 3860 3861
# ['(0.3-1.7)'] 0.1
# 3862 3864
# ['(0.8-2.1)', '0.9'] NA 1
# 3867 3868
# ['1.0'] 76.2
# 3869 3870
# ['1.0'] 1.2
# 3871 3872
# ['8.4'] 87.6
# 3873 3874
# ['2.5'] 4.4
# 3877 3878
# ['agoraphobia;'] 3.0
# 3879 3880
# ['panic'] 67.9
# 3881 3882
# ['PD,'] 5.5
# 3883 3885
# ['disorder;', 'PA'] 90.7 4
# 3885 3886
# ['only,'] Lifetime
# 3888 3889
# ['of'] 12.0
# 3890 3891
# ['but'] 1.1
# 3892 3893
# ['PD'] 10.7
# 3894 3895
# ['AG;'] 4.1
# 3896 3897
# ['lifetime'] 100.0
# 3898 3899
# ['of'] 0
# 3900 3901
# ['with'] 100.0
# 3902 3903
# ['but'] 0
# 3904 3905
# ['PD;'] 0.1
# 3910 3911
# ['PD'] PA
# 3911 3912
# ['without'] 22.7
# 3913 3914
# ['PD-AG,'] 0.5
# 3915 3916
# ['history'] 22.1
# 3917 3918
# ['PD'] 1.7
# 3919 3920
# ['AG.'] 22.7
# 3921 3922
# ['on'] 0.8
# 3923 3924
# ['logistic'] 21.5
# 3925 3926
# ['analyses'] 1.0
# 3927 3928
# ['separately'] 0.9
# 3928 3929
# ['compare'] PD
# 3930 3933
# ['in', 'each', 'of'] NA NA 23.6
# 3934 3935
# ['4'] 0.9
# 3936 3937
# ['subgroups'] 22.9
# 3938 3939
# ['respondents'] 1.0
# 3940 3941
# ['have'] 0.5
# 3941 3942
# ['no'] AG
# 3943 3944
# ['history'] NA
# 3946 3947
# ['the'] 1.8
# 3948 3950
# ['sizes', 'differ'] NA 17.0
# 3951 3952
# ['respondents'] 1.4
# 3958 3959
# ['exclusive'] 2
# 3959 3960
# ['panic'] 3
# 3960 3961
# ['subgroups'] 12-mo
# 3963 3964
# ['only,'] 35.7
# 3965 3966
# ['PA-AG,'] 1.5
# 3967 3968
# ['PD'] 41.1
# 3969 3970
# ['and'] 5.5
# 3971 3972
# ['PD-AG)'] 57.4
# 3973 3974
# ['compared'] 3.7
# 3975 3976
# ['with'] 62.6
# 3977 3978
# ['3500'] 4.4
# 3981 3982
# ['no'] Years
# 3984 3985
# ['panic.'] 4.7
# 3986 3987
# ['at'] 0.2
# 3988 3989
# ['P.05'] 6.6
# 3990 3991
# ['2-sided'] 1.1
# 3992 3993
# ['(REPRINTED)'] 8.3
# 3994 3995
# ['GEN'] 0.6
# 3996 3997
# ['63,'] 10.7
# 3998 3999
# ['2006'] 1.1
# 4000 4001
# ['419'] 20.4
# 4001 4002
# ['©2006'] 1
# 4002 4003
# ['American'] Lifetime
# 4005 4006
# ['All'] 38.3
# 4007 4008
# ['reserved.'] 4.5
# 4009 4010
# ['From:'] 78.2
# 4011 4012
# ['on'] 16.0
# 4013 4014
# ['\x0cspondents'] 121.8
# 4015 4016
# ['the'] 11.9
# 4017 4018
# ['subgroup'] 134.4
# 4019 4020
# ['higher'] 20.7
# 4021 4023
# ['ratings', '(45.3%'] 18.2 4
# 4023 4024
# ['with'] Lifetime
# 4026 4027
# ['severe'] 31.0
# 4028 4029
# ['and'] 4.5
# 4030 4031
# ['with'] 131.4
# 4032 4033
# ['rating)'] 29.4
# 4034 4035
# ['those'] 31.3
# 4036 4037
# ['the'] 2.7
# 4038 4039
# ['subgroup'] 46.0
# 4040 4041
# ['with'] 7.8
# 4042 4043
# ['or'] 4.3
# 4044 4045
# ['rating,'] 1
# 4048 4049
# ['severe'] 6.0
# 4050 4051
# ['Summary'] 0.3
# 4052 4053
# ['ratings'] 9.2
# 4054 4055
# ['role'] 2.2
# 4056 4057
# ['are'] 17.2
# 4058 4059
# ['to'] 8.8
# 4060 4061
# ['ratings'] 34.1
# 4062 4063
# ['being'] 70.4
# 4064 4065
# ['in'] NA
# 4066 4067
# ['PD-AG'] 4
# 4067 4068
# ['subgroup'] lifetime
# 4070 4071
# ['moderate'] 11.5
# 4072 4073
# ['severe'] 0.9
# 4074 4075
# ['and'] 100.2
# 4076 4077
# ['with'] 48.3
# 4078 4079
# ['rating)'] 10.0
# 4080 4081
# ['lowest'] 0.7
# 4084 4085
# ['subgroup'] 3.5
# 4086 4088
# ['with', 'moderate'] NA Abbreviations
# 4089 4090
# ['severe'] AG
# 4093 4094
# ['with'] NA
# 4098 4099
# ['ratings,'] PA
# 4103 4104
# ['has'] PD
# 4108 4109
# ['with'] PA
# 4114 4115
# ['39.0%'] PA
# 4118 4121
# ['than', 'the', 'PDonly'] PD or AG
# 4122 4125
# ['(76.8%', 'with', 'moderate'] PA-AG
# 4129 4130
# ['56.2%'] PA
# 4131 4132
# ['severe'] AG
# 4135 4136
# ['modal'] PD
# 4137 4138
# ['is'] PD
# 4143 4144
# ['other'] PD
# 4145 4146
# ['in'] AG
# 4147 4150
# ['PA-only', 'subgroup.', 'In'] PD-AG
# 4154 4155
# ['rating'] PD
# 4156 4157
# ['no'] AG
# 4187 4188
# ['are'] 2-sided
# 4190 4191
# ['the'] 100
# 4194 4195
# ['PA-only'] 50
# 4195 4196
# ['(61.1%)'] 30
# 4196 4197
# ['subgroups.'] 10
# 4198 4200
# ['proportions', 'that'] 40 20
# 4209 4210
# ['treatment'] 60
# 4212 4215
# ['PD-only', '(70.3%', 'vs'] PA-AG
# 4217 4220
# ['PD-AG', '(85.0%', 'vs'] PD-AG
# 4221 4222
# ['subgroups,'] 100
# 4222 4225
# ['but', 'substantially', 'lower'] Age of Onset
# 4227 4229
# ['PA-only', '(16.2%'] Cumulative Probability
# 4233 4234
# ['(37.6%'] 2
# 4239 4240
# ['common'] first
# 4244 4245
# ['the'] 4
# 4247 4248
# ['sector'] lifetime
# 4251 4253
# ['the', '4'] 2 3
# 4254 4255
# ['(32.3%-70.4%).'] 6.9
# 4256 4257
# ['exception'] P=.07
# 4263 4264
# ['health'] 1
# 4278 4279
# ['treatment,'] 63
# 4280 4281
# ['proportion'] APR
# 4283 4284
# ['cases'] 418
# 4285 4286
# ['received'] 2006
# 4286 4289
# ['treatment', 'in', 'the'] American Medical Association
# 4300 4301
# ['in']
# 4303 4305
# ['subgroup', '(45.7%),'] 83.1%
# 4307 4308
# ['in'] PD
# 4313 4315
# ['(66.9%)', 'subgroups.'] 100%
# 4318 4319
# ['the'] 2
# 4331 4332
# ['all'] 4
# 4341 4342
# ['(52.7%'] PA
# 4359 4360
# ['treatment'] AG
# 4364 4365
# ['general'] PD
# 4370 4373
# ['in', 'any', 'other'] PA-AG
# 4375 4378
# ['each', 'Table', '3.'] 4.4-24.0
# 4384 4385
# ['Panic'] PD
# 4389 4392
# ['Disorders*', 'Disorder', 'PA'] 2.0-5.4
# 4399 4402
# ['Percentage', 'OR', '(95%'] PD-AG
# 4404 4407
# ['OR', '(95%', 'CI)'] 2.5-25.8
# 4423 4426
# ['(1.7-3.2)', '31.9', '8.5'] PA-AG
# 4428 4431
# ['4.4', '(2.9-6.8)', '15.0'] 3.2-5.1
# 4436 4437
# ['21.0'] PD
# 4441 4444
# ['(13.8-41.4)', '34.3', '3.8'] 3.5-5.4
# 4448 4451
# ['153.8', 'Social', 'phobia'] PD-AG
# 4453 4454
# ['(1.6-2.4)'] 5.6
# 4475 4476
# ['(3.4-7.5)'] 3
# 4476 4477
# ['39.6'] AG
# 4478 4479
# ['(6.8-19.7)'] PD
# 4486 4489
# ['NA', '8.2', '5.4'] 3.4-5.8
# 4491 4494
# ['20.2', '(5.5-73.9)', '20.8'] TWELVE-MONTH
# 4494 4495
# ['Separation'] CLINICAL
# 4498 4500
# ['3.1', '(2.3-4.0)'] IMPAIRMENT Summary
# 4509 4510
# ['40.6'] four
# 4510 4511
# ['Any'] 12-month
# 4514 4516
# ['45.0', '3.2'] 2 3
# 4517 4520
# ['94.9', '77.9', '(24.9-244.1)'] 34.3-102.9
# 4521 4522
# ['7.2'] P.001
# 4530 4533
# ['depressive', 'disorder', '28.2'] PD-AG
# 4535 4537
# ['48.7', '4.4'] 86.3%
# 4544 4546
# ['8.2', 'Dysthymia'] 42.4%
# 4555 4556
# ['14.6'] PA
# 4560 4562
# ['disorder', 'I'] 6.7%
# 4569 4571
# ['(2.7-9.6)', '14.4'] 0.3%
# 4577 4578
# ['Any'] 4
# 4581 4582
# ['2.5'] 2
# 4586 4587
# ['50.0'] 4
# 4593 4596
# ['Impulse-control', 'disorders', 'Attention-deficit/hyperactivity'] Characteristic Odds Ratio
# 4597 4599
# ['11.7', '2.3'] 95%
# 4607 4608
# ['20.0'] 5172
# 4609 4612
# ['defiant', 'disorder', '13.6'] PA-AG
# 4615 4616
# ['NA'] 3572
# 4622 4623
# ['Conduct'] 3844
# 4624 4627
# ['12.3', '1.9', '(1.4-2.6)'] PD-AG
# 4630 4631
# ['4.2'] 3604
# 4635 4638
# ['Intermittent', 'explosive', 'disorder'] 18-29
# 4638 4639
# ['7.8'] 1.0
# 4639 4642
# ['1.7', '(1.3-2.2)', '21.8'] 1.0 1.0 1.0
# 4647 4650
# ['9.0', '1.7', '(0.8-3.6)'] 0.7-1.3
# 4651 4653
# ['Any', 'impulse-control'] 1.6 (
# 4653 4658
# ['disorder', '33.7', '2.3', '(1.8-2.8)', '63.2'] 0.6-4.4) 1.5
# 4659 4662
# ['47.2', '4.3', '(2.8-6.6)'] 1.1-2.1
# 4663 4664
# ['NA'] 1.7
# 4665 4668
# ['Substance', 'use', 'disorders'] 1.0-2.8
# 4669 4670
# ['abuse'] 45
# 4674 4677
# ['(1.8-2.7)', '27.0', '3.2'] 0.7-1.2
# 4678 4679
# ['25.0'] 1.7
# 4680 4683
# ['(2.5-4.9)', '37.3', '5.6'] 0.5-6.0
# 4686 4689
# ['dependence', '8.5', '2.4'] 0.9-1.8
# 4690 4692
# ['14.2', '4.0'] 1.3 (
# 4692 4695
# ['(1.6-9.7)', '12.8', '4.1'] 0.7-2.4
# 4696 4698
# ['23.4', '7.3'] 60 0.4
# 4699 4704
# ['12.1', 'Illicit', 'drug', 'abuse', 'or'] 0.2-0.6) 0.5
# 4705 4706
# ['13.0'] 0.1
# 4711 4714
# ['17.5', '3.6', '(2.3-5.4)'] 0.2-0.7
# 4715 4716
# ['3.9'] 0.1
# 4721 4722
# ['5.6'] 2
# 4722 4723
# ['3.0'] 29.2
# 4723 4724
# ['(2.0-4.4)'] 4.0
# 4724 4728
# ['10.6', '5.8', '(2.1-16.0)', '9.1'] 24.2 35.5 Sex Male
# 4728 4729
# ['5.2'] 1.0
# 4729 4730
# ['(3.1-8.7)'] 1.0
# 4730 4733
# ['9.3', '4.6', '(1.9-10.9)'] 1.0 1.0 Female
# 4733 4734
# ['6.0'] 1.4
# 4735 4738
# ['substance', 'use', 'disorder'] 1.2-1.7
# 4741 4745
# ['31.4', '3.5', '(1.8-6.9)', '27.0'] 0.8-2.3)
# 4745 4746
# ['3.3'] 2.3
# 4747 4750
# ['37.3', '4.8', '(2.4-9.5)'] 1.8-3.0
# 4751 4752
# ['Any'] 2.0
# 4753 4756
# ['71.9', '3.3', '(2.8-4.1)'] 1.3-3.2
# 4757 4758
# ['NA'] 2
# 4758 4759
# ['83.1'] 16.5
# 4759 4760
# ['6.5'] 1.2
# 4760 4761
# ['(3.7-11.7)'] 38.6
# 4761 4762
# ['100.0'] 9.1
# 4762 4764
# ['NA', '5.3'] Race Hispanic
# 4766 4767
# ['agoraphobia;'] 0.4
# 4770 4771
# ['NA,'] 1.0
# 4772 4773
# ['applicable;'] 0.3
# 4776 4778
# ['PA,', 'panic'] 0.8 (
# 4778 4779
# ['attack;'] 0.5
# 4784 4787
# ['lifetime', 'history', 'of'] 0.3-2.1
# 4791 4795
# ['or', 'AG;', 'PA-AG,', 'lifetime'] 0.5-0.8)
# 4795 4796
# ['history'] 0.6
# 4797 4800
# ['PA', 'with', 'AG'] 0.3-1.5
# 4803 4807
# ['PD', 'only,', 'lifetime', 'history'] 0.3-0.6)
# 4807 4808
# ['of'] 0.5
# 4809 4812
# ['without', 'AG;', 'PD-AG,'] 0.2-1.0
# 4814 4815
# ['of'] 1.0
# 4816 4819
# ['with', 'AG.', '*Based'] 0.6-1.5
# 4822 4825
# ['multivariate', 'logistic', 'regression'] 0.6-7.0
# 4826 4827
# ['for'] 1.1
# 4828 4831
# ['row', 'of', 'the'] 0.6-2.0
# 4834 4836
# ['dummy', 'variables'] 0.2-
# 4838 4840
# ['4', 'panic'] White 1.0
# 4840 4841
# ['subgroups'] 1.0
# 4841 4842
# ['are'] 1.0
# 4843 4845
# ['to', 'predict'] 2 27.7
# 4845 4847
# ['lifetime', 'occurrence'] 2.5 23.5
# 4848 4849
# ['the'] Education
# 4851 4854
# ['controlling', 'for', 'age'] 0-11
# 4856 4857
# ['(in'] 1.0
# 4858 4860
# ['age', 'intervals),'] 12 1.0
# 4861 4864
# ['and', 'race-ethnicity.', 'The'] 0.7-1.3
# 4867 4871
# ['in', 'each', 'of', 'the'] 0.3-1.7)
# 4873 4876
# ['subgroups', 'with', 'respondents'] 0.6-1.3
# 4877 4878
# ['have'] 0.9
# 4879 4882
# ['lifetime', 'history', 'of'] 0.4-2.1
# 4883 4886
# ['Significant', 'at', 'the'] 13-15
# 4888 4891
# ['2-sided', 'test.', 'Insufficient'] 0.7-1.2
# 4892 4893
# ['for'] 0.9
# 4894 4897
# ['because', 'of', 'the'] 0.4-2.0
# 4898 4899
# ['prevalence'] 1.2
# 4900 4902
# ['PA-AG', 'and'] 0.8-
# 4906 4908
# ['PSYCHIATRY/VOL', '63,'] 0.3-
# 4913 4916
# ['American', 'Medical', 'Association.'] 0.7-1.2
# 4917 4918
# ['rights'] 0.5
# 4919 4922
# ['Downloaded', 'From:', 'http://archpsyc.jamanetwork.com/'] 0.2-1.5
# 4923 4925
# ['04/10/2014', '\x0cof'] 0.8 (
# 4925 4926
# ['the'] 0.5
# 4929 4930
# ['The'] 0.7
# 4931 4934
# ['that', 'obtained', 'treatment'] 0.3-2.1
# 4935 4936
# ['with'] 2
# 4937 4938
# ['treatment'] 1.9
# 4938 4939
# ['guidelines'] 10.3
# 4939 4941
# ['did', 'not'] 0.7 Marital
# 4942 4945
# ['markedly', 'across', 'the'] Married/cohabitating
# 4945 4950
# ['3', 'subgroups', 'with', 'PD', 'or'] 1.0 1.0 1.0 1.0 Separated
# 4954 4955
# ['meeting'] 1.1
# 4956 4959
# ['guidelines', 'was', 'received'] 0.8-1.4
# 4960 4961
# ['a'] 2.2
# 4962 4965
# ['lower', 'proportion', 'of'] 1.1-4.2
# 4968 4971
# ['PA-only', 'subgroup', '(18.2%),'] 1.2-2.1
# 4972 4973
# ['treatment'] 1.3
# 4974 4977
# ['apply', 'to', 'PD'] 0.7-2.3
# 4980 4981
# ['to'] 1.0
# 4982 4985
# ['PAs.', 'COMMENT', 'These'] 0.8-1.2
# 4986 4987
# ['should'] 1.2
# 4988 4989
# ['interpreted'] 0.5
# 4992 4993
# ['several'] 1.2
# 4994 4997
# ['First,', 'the', 'response'] 0.8-1.8
# 4998 4999
# ['was'] 0.9
# 5000 5003
# ['70%.', 'As', 'described'] 0.4-2.0
# 5004 5005
# ['more'] 2
# 5006 5007
# ['elsewhere,15'] 6.3
# 5007 5008
# ['we'] 10.3
# 5011 5017
# ['in', 'a', 'nonrespondent', 'survey', 'in', 'which'] Working 1.0 1.0 1.0 1.0 Student
# 5019 5022
# ['of', 'initial', 'nonrespondents'] 0.5-1.4
# 5023 5025
# ['offered', 'a'] 0.8 (
# 5025 5028
# ['large', 'financial', 'incentive'] 0.2-3.5
# 5029 5030
# ['to'] 0.4
# 5035 5036
# ['interview'] 1.5
# 5037 5038
# ['included'] 0.5
# 5041 5042
# ['questions.'] Homemaker
# 5044 5047
# ['difference', 'was', 'found'] 0.5-1.3
# 5048 5049
# ['panic'] 2.0
# 5050 5053
# ['question', 'endorsement', 'compared'] 0.8-5.1
# 5054 5055
# ['responses'] 1.1
# 5056 5059
# ['the', 'main', 'survey'] 0.7-1.7
# 5060 5062
# ['indirectly', 'arguing'] 1.3 (
# 5062 5063
# ['against'] 0.5
# 5066 5068
# ['on', 'the'] Retired 1.0
# 5069 5072
# ['of', 'panic.', 'Second,'] 0.6-1.5
# 5075 5078
# ['with', 'SCID', 'PD'] 0.2-6.6
# 5079 5080
# ['was'] 1.0
# 5081 5082
# ['no'] 0.5
# 5085 5086
# ['obtained'] 4.3
# 5087 5090
# ['PA', 'or', 'AG.'] 1.6-11.3
# 5092 5093
# ['biased'] 1.1
# 5094 5097
# ['about', 'AOO,', 'persistence,'] 0.9-1.5
# 5098 5099
# ['other'] 3.6
# 5100 5103
# ['course', 'and', 'treatment'] 1.8-7.1
# 5104 5105
# ['were'] 1.5
# 5106 5107
# ['retrospectively.'] 1.0
# 5110 5111
# ['more'] 3.8
# 5112 5115
# ['elsewhere,16', 'a', 'number'] 2.1-6.8
# 5116 5117
# ['strategies'] 2
# 5118 5119
# ['used'] 18.4
# 5120 5121
# ['the'] 30.9
# 5121 5122
# ['NCS-R'] Annual
# 5127 5128
# ['exists'] 0.9
# 5133 5136
# ['accuracy', 'of', 'retrospective'] 0.5-2.3
# 5137 5138
# ['reports,30'] 1.3
# 5139 5140
# ['we'] 0.9
# 5143 5144
# ['about'] 1.4
# 5145 5148
# ['on', 'other', 'aspects'] 0.6-3.2
# 5152 5153
# ['limitations'] 1.0
# 5154 5157
# ['a', 'backdrop,', 'the'] 0.8-1.2
# 5158 5159
# ['lifetime'] 0.9
# 5160 5163
# ['estimates', 'of', 'DSM-IV'] 0.4-2.0
# 5164 5165
# ['and'] 1.4
# 5166 5169
# ['(4.7%', 'and', '1.1%,'] 0.9-2.1
# 5170 5172
# ['are', 'similar'] 0.8 (
# 5172 5175
# ['to', 'the', 'DSM-III-R1'] 0.4-1.7
# 5179 5180
# ['NCS'] 1.2
# 5181 5184
# ['and', '1.5%,', 'respectively).'] 1.0-1.4
# 5185 5186
# ['NCS-R'] 0.7
# 5187 5188
# ['of'] 0.3
# 5193 5196
# ['higher', 'than', 'in'] 0.8-2.1
# 5197 5198
# ['NCS'] 0.9
# 5199 5202
# ['Although', 'higher', 'than'] 0.5-1.6
# 5204 5205
# ['epidemiological'] 1.0
# 5206 5207
# ['the'] 1.0
# 5207 5209
# ['concordance', 'of'] 1.0 2
# 5210 5211
# ['NCS-R'] 0.9
# 5211 5213
# ['PD', 'prevalence'] 2.5 2.2
# 5213 5216
# ['estimate', 'with', 'an'] Abbreviations: AG
# 5219 5220
# ['argues'] PA
# 5224 5225
# ['the'] PD
# 5229 5230
# ['concern'] PA
# 5235 5236
# ['upward'] PA
# 5238 5241
# ['the', 'CIDI', 'requirement'] PD or AG
# 5242 5245
# ['anxiety', 'about', 'multiple'] PA-AG
# 5249 5250
# ['the'] PA
# 5251 5252
# ['requirement.'] AG
# 5254 5255
# ['persistence,'] PD
# 5256 5257
# ['correlates,'] PD
# 5262 5263
# ['consistent'] PD
# 5264 5265
# ['the'] AG
# 5266 5269
# ['NCS1,2,32', 'and', 'other'] PD-AG
# 5273 5274
# ['direct'] PD
# 5275 5276
# ['is'] AG
# 5292 5293
# ['prevalence'] 4
# 5315 5316
# ['survey'] 4
# 5321 5322
# ['a'] 1672
# 5322 5323
# ['much'] PA
# 5325 5326
# ['lifetime'] 72
# 5326 5329
# ['prevalence', 'of', 'PAs'] PA-AG
# 5330 5331
# ['the'] 344
# 5331 5332
# ['NCS-R'] PD
# 5335 5339
# ['the', 'NCS', '(7.3%),', 'a'] 104 PD-AG
# 5345 5346
# ['detailed'] 3500
# 5357 5358
# ['the'] P.05
# 5360 5361
# ['that'] 2-sided
# 5364 5372
# ['underestimated', 'in', 'the', 'baseline', 'NCS.', 'We', 'are', 'aware'] REPRINTED) ARCH GEN PSYCHIATRY/VOL 63
# 5373 5374
# ['no'] APR
# 5376 5377
# ['population'] 419
# 5377 5378
# ['research'] ©
# 5378 5379
# ['in'] 2006
# 5379 5382
# ['which', 'investigators', 'compared'] American Medical Association
# 5393 5394
# ['without']
# 5397 5400
# ['striking', 'results', 'of'] PA-AG
# 5406 5408
# ['are', 'common'] 45.3%
# 5415 5417
# ['These', 'results'] 20.2%
# 5425 5426
# ['people'] PD
# 5430 5432
# ['to', 'meet'] 46.1%
# 5439 5441
# ['uncued', 'attacks,'] 6.0%
# 5446 5448
# ['cued', 'attacks.'] Summary SDS
# 5461 5465
# ['attacks', 'even', 'among', 'people'] the PD-AG
# 5467 5469
# ['This', 'finding'] 95.0%
# 5476 5478
# ['uncovers', 'initially'] 84.7%
# 5486 5487
# ['probably'] PA
# 5491 5493
# ['proportion', 'of'] 21.3%
# 5500 5502
# ['that', 'persistence'] 11.1%
# 5514 5517
# ['to', 'AG;', 'that'] PA-AG
# 5520 5521
# ['other'] SDS
# 5523 5525
# ['is', 'more'] 58.8%
# 5532 5534
# ['and', 'that'] 39.0%
# 5543 5545
# ['they', 'occur'] 76.8%
# 5552 5554
# ['suggest', 'that'] 56.2%
# 5567 5568
# ['respondents'] 3
# 5573 5574
# ['met'] PA
# 5589 5591
# ['4.', 'Clinical'] 70.6%
# 5597 5598
# ['in'] PD
# 5612 5613
# ['(n'] AG
# 5614 5616
# ['701)*', 'PA-AG'] 96.1%
# 5620 5622
# ['Only', '(n'] 84.8%
# 5625 5626
# ['(n'] 5
# 5628 5629
# ['Clinical'] Lifetime
# 5634 5638
# ['(7.1)', '6.0', '(2.5)', '42.4'] the PA-AG
# 5639 5641
# ['34.3', 'Moderate'] 74.7%
# 5643 5644
# ['25.1'] PA
# 5647 5649
# ['43.9', '(10.1)'] 61.1%
# 5669 5670
# ['Impairment§'] PD
# 5673 5675
# ['39.0', '(7.9)'] 70.3%
# 5676 5678
# ['(5.0)', '84.7'] 84.8%
# 5680 5683
# ['Moderate', '10.2', '(1.5)'] PD-AG
# 5684 5686
# ['(8.0)', '20.6'] 85.0%
# 5687 5689
# ['10.3', '(5.0)'] 96.1%
# 5697 5698
# ['5.0'] PA
# 5701 5703
# ['70.6', '(2.0)'] 16.2%
# 5704 5706
# ['(8.8)', '9.4'] 61.1%
# 5708 5711
# ['62.9', 'Abbreviations:', 'AG,'] PA-AG
# 5712 5714
# ['NA,', 'not'] 37.6%
# 5715 5717
# ['PA,', 'panic'] 74.7%
# 5732 5733
# ['PA-AG,'] 3
# 5735 5736
# ['of'] 4
# 5738 5740
# ['AG', 'but'] 32.3%-70.4%
# 5745 5748
# ['history', 'of', 'PD'] PA-AG
# 5756 5758
# ['AG.', '*The'] 46.1%
# 5768 5770
# ['does', 'not'] 42.7%
# 5780 5781
# ['estimate'] 12month
# 5786 5788
# ['table', 'because'] the year
# 5794 5797
# ['and', 'the', 'sample'] PD-AG
# 5799 5801
# ['the', 'actual'] 72.6%
# 5806 5807
# ['original'] PA
# 5811 5813
# ['categories', 'of'] 45.7%
# 5818 5822
# ['collapsed', 'to', 'define', 'the'] the PA-AG
# 5823 5825
# ['category', 'reported'] 60.8%
# 5827 5828
# ['at'] PD
# 5831 5833
# ['2-sided', 'test.'] 66.9%
# 5844 5845
# ['home,'] 12-month
# 5859 5860
# ['across'] PD
# 5863 5868
# ['original', 'Sheehan', 'Disability', 'Scale', 'categories'] 43.9% vs 66.9%
# 5870 5873
# ['and', 'very', 'severe'] PD-AG
# 5874 5876
# ['collapsed', 'to'] 52.7%
# 5877 5879
# ['the', 'severe'] 72.6%
# 5884 5885
# ['number'] PA
# 5888 5890
# ['at', 'least'] 14.7%
# 5891 5893
# ['impairment', 'is'] 45.7%
# 5895 5898
# ['inverse', 'of', 'the'] PA-AG
# 5899 5901
# ['with', 'no'] 29.7%
# 5902 5904
# ['the', '2'] 60.8%
# 5907 5910
# ['this', 'row', 'is'] Twelve-month
# 5928 5929
# ['American'] 3
# 5932 5933
# ['rights'] 4
# 5948 5952
# ['people', 'with', 'PA-AG40', 'and'] PA-AG PD
# 5953 5956
# ['of', 'people', 'with'] PD-AG
# 5956 5957
# ['PD-AG'] 2
# 5957 5958
# ['compared'] 3
# 5961 5963
# ['PD', 'only.39,41'] 95%
# 5963 5964
# ['Family'] CI
# 5968 5970
# ['that', 'AG'] 95%
# 5970 5971
# ['and'] CI
# 5975 5977
# ['least', 'some'] 95%
# 5977 5978
# ['distinct'] CI
# 5982 5984
# ['same', 'time,'] 95%
# 5984 5985
# ['our'] CI
# 5989 5990
# ['prevalence'] Generalized
# 5992 5993
# ['among'] 10.0
# 5993 5994
# ['people'] 2.4
# 5995 5998
# ['PD', 'than', 'PA'] 1.7-3.2
# 5999 6001
# ['consistent', 'with'] 31.9 8.5
# 6002 6005
# ['strong', 'association', 'between'] 4.9-14.6
# 6006 6008
# ['and', 'PD'] 21.3 4.4
# 6009 6012
# ['observed', 'in', 'clinical'] 2.9-6.8
# 6013 6015
# ['The', 'subgroup'] 15.0 2.6
# 6016 6019
# ['document', 'monotonic', 'increases'] 1.4-4.8
# 6020 6021
# ['PA'] 33.6
# 6023 6024
# ['PD-AG'] 21.0
# 6024 6025
# ['in'] 2.4
# 6026 6029
# ['of', 'attacks,', 'comorbidity,'] 2.0-3.0
# 6030 6032
# ['severity,', 'role'] 73.7 24.0
# 6033 6036
# ['and', 'treatment', 'seeking,'] 13.8-41.4
# 6037 6039
# ['intermediate', 'values'] 34.3 3.8
# 6040 6045
# ['PA-AG', 'and', 'PD', 'only.', 'Together'] 2.7-5.3) 75.2
# 6047 6050
# ['finding', 'that', 'a'] 14.3-46.6
# 6051 6052
# ['proportion'] 153.8
# 6054 6055
# ['is'] 18.8
# 6055 6056
# ['associated'] 1.9
# 6057 6060
# ['PA,', 'these', 'results'] 1.6-2.4
# 6061 6062
# ['be'] 65.5
# 6064 6067
# ['suggesting', 'that', 'panic'] 7.7-35.8
# 6068 6069
# ['along'] 31.1
# 6071 6074
# ['in', 'which', 'PA'] 2.3-4.2
# 6076 6077
# ['differ'] 15.5
# 6078 6079
# ['degree'] 9.3
# 6082 6083
# ['kind.'] 82.4
# 6086 6088
# ['consistent', 'with'] 12.0 3.0
# 6089 6092
# ['findings', 'that', 'infrequent,'] 2.3-3.9
# 6096 6097
# ['in'] 2.3
# 6100 6101
# ['that'] 21.6
# 6101 6106
# ['these', 'attacks', 'typically', 'include', 'fewer'] 5.0 (3.4-7.5
# 6107 6108
# ['less'] 39.6
# 6110 6113
# ['than', 'those', 'in'] 6.8-19.7
# 6114 6115
# ['with'] 40.7
# 6119 6121
# ['PA', 'aggregates'] 2.1 1.5
# 6122 6125
# ['PD', 'in', 'families.40,44'] 0.5-4.3
# 6126 6127
# ['distinction'] 0
# 6128 6130
# ['cued', 'and'] 8.2 5.4
# 6131 6134
# ['attacks', 'might', 'be'] 1.8-16.1
# 6135 6137
# ['into', 'question'] 19.6 20.2
# 6138 6139
# ['part'] 5.5
# 6142 6144
# ['line', 'of'] 20.8 Separation
# 6146 6147
# ['on'] 7.7
# 6147 6148
# ['the'] 3.1
# 6149 6152
# ['that', 'most', 'PAs'] 2.3-4.0
# 6154 6155
# ['some'] 6.3
# 6160 6162
# ['premature', 'to'] 11.0 4.4
# 6167 6168
# ['the'] 23.5
# 6170 6171
# ['PA'] 7.1
# 6174 6175
# ['arbitrary.'] 40.6
# 6179 6180
# ['prevalence'] 45.0
# 6182 6183
# ['only'] 2.7
# 6186 6188
# ['outcomes', 'associated'] 94.9 77.9
# 6189 6192
# ['PA', 'only,', 'future'] 24.9-244.1
# 6193 6194
# ['whether'] 66.0
# 6196 6197
# ['or'] 5.5
# 6200 6202
# ['PD', 'should'] 93.6 56.2
# 6203 6206
# ['modified', 'to', 'improve'] 22.4-141.0
# 6207 6208
# ['between'] 143.7
# 6208 6209
# ['pathological'] Mood
# 6213 6215
# ['An', 'innovation'] 28.2 2.1
# 6216 6219
# ['the', 'NCS-R', 'was'] 1.8-2.4
# 6221 6222
# ['of'] 4.4
# 6223 6226
# ['fully', 'structured', 'version'] 2.6-7.4
# 6227 6229
# ['the', 'PDSS'] 34.7 2.0
# 6230 6233
# ['assess', 'clinical', 'severity.'] 1.5-2.7
# 6234 6235
# ['lower'] 38.5
# 6237 6240
# ['clinical', 'samples,', '86.3%'] 1.5-4.0
# 6241 6242
# ['respondents'] 8.2
# 6242 6244
# ['with', 'PD-AG'] Dysthymia 5.0
# 6246 6249
# ['to', '46.1%', 'of'] 2.4-4.3
# 6250 6252
# ['with', 'PA-AG'] 10.0 5.0
# 6253 6256
# ['PD', 'only', 'were'] 2.1-12.0
# 6257 6259
# ['the', 'clinically'] 9.6 5.0
# 6260 6263
# ['range', 'on', 'the'] 2.9-8.8
# 6264 6266
# ['A', 'related'] 14.6 8.9
# 6267 6270
# ['is', 'that', 'clinical'] 4.2-18.8
# 6271 6272
# ['assessed'] 6.9
# 6278 6279
# ['assessed'] 2.8
# 6280 6283
# ['the', 'SDS', 'appear'] 2.3-3.5
# 6287 6290
# ['as', 'much', 'by'] 2.7-9.6
# 6291 6293
# ['(PA-AG', 'vs'] 14.4 5.4
# 6294 6297
# ['only)', 'as', 'by'] 3.6-7.9
# 6298 6300
# ['(PD', 'only'] 33.0 13.6
# 6301 6304
# ['PA', 'only).', 'This'] 8.0-23.2
# 6305 6306
# ['is'] 52.3
# 6309 6311
# ['findings', 'that'] 36.0 2.5
# 6312 6315
# ['is', 'associated', 'with'] 2.2-2.8
# 6317 6318
# ['anticipatory'] 7.1
# 6319 6322
# ['and', 'cognitive', 'correlates'] 4.1-12.3
# 6323 6325
# ['severity41,47-49', 'and'] 50.0 3.3
# 6326 6329
# ['finding', 'that', 'AG'] 2.4-4.5
# 6330 6332
# ['more', 'common'] 73.3 10.0
# 6333 6336
# ['people', 'with', 'PD'] 5.0-19.9
# 6337 6338
# ['PA.'] 35.3
# 6342 6344
# ['pattern', 'is'] Attention-
# 6348 6350
# ['number', 'of'] 11.7 2.3
# 6351 6354
# ['among', 'respondents', 'with'] 1.6-3.3
# 6355 6356
# ['those'] 28.8
# 6356 6357
# ['without'] NA
# 6357 6359
# ['AG', 'in'] 13.0 2.6
# 6360 6363
# ['the', 'PA', 'and'] 1.5-4.5
# 6364 6365
# ['samples.'] 36.2
# 6365 6366
# ['One'] NA
# 6370 6372
# ['pattern', 'is'] 13.6 2.5
# 6373 6376
# ['AG', 'is', 'a'] 1.8-3.5
# 6377 6378
# ['marker'] 12.2
# 6378 6379
# ['of'] NA
# 6379 6381
# ['panic,', 'although'] 13.0 2.4
# 6382 6385
# ['is', 'at', 'least'] 1.5-3.7
# 6386 6387
# ['inconsistent'] 27.6
# 6387 6390
# ['with', 'the', 'notion'] NA 7.3 Conduct
# 6391 6393
# ['previous', 'paragraphs'] 12.3 1.9
# 6394 6397
# ['AG', 'is', 'distinct'] 1.4-2.6
# 6398 6399
# ['PD'] 12.4
# 6399 6400
# ['disorder.'] NA
# 6401 6402
# ['possibility'] 4.2
# 6403 6404
# ['that'] 2.8
# 6407 6408
# ['direct'] 22.5
# 6408 6409
# ['effect'] NA
# 6409 6410
# ['on'] 18.8
# 6413 6414
# ['results'] 7.8
# 6416 6419
# ['with', 'previous', 'NCS-R'] 1.3-2.2
# 6420 6422
# ['that', 'most'] 21.8 5.3
# 6423 6426
# ['with', 'PD', 'eventually'] 2.4-11.6
# 6427 6429
# ['treatment,23', 'that'] 11.8 2.5
# 6430 6433
# ['active', 'cases', 'receive'] 1.4-4.4
# 6434 6436
# ['in', 'a'] 9.0 1.7
# 6441 6442
# ['current'] 9.5
# 6447 6449
# ['PD', 'and/or'] 33.7 2.3
# 6450 6453
# ['subgroups)', 'fails', 'to'] 1.8-2.8
# 6454 6455
# ['basic'] 63.2
# 6455 6456
# ['treatment'] NA
# 6456 6458
# ['guidelines.50', 'The'] 47.2 4.3
# 6459 6462
# ['result', 'is', 'all'] 2.8-6.6
# 6463 6464
# ['more'] 59.5
# 6464 6465
# ['striking'] NA
# 6465 6466
# ['in'] 24.6
# 6473 6475
# ['liberal.', 'For'] 19.3 2.2
# 6476 6479
# ['no', 'distinction', 'was'] 1.8-2.7
# 6480 6481
# ['among'] 27.0
# 6483 6486
# ['much', 'more', 'evidence'] 1.5-6.7
# 6487 6489
# ['the', 'effectiveness'] 25.0 3.5
# 6490 6493
# ['some', 'types', 'of'] 2.5-4.9
# 6494 6496
# ['than', 'others'] 37.3 5.6
# 6497 6500
# ['treating', 'panic,51-53', 'nor'] 2.7-11.5
# 6501 6502
# ['a'] 11.5
# 6502 6503
# ['distinction'] Alcohol
# 6504 6506
# ['among', 'antidepressants'] 8.5 2.4
# 6507 6510
# ['anxiolytics', 'despite', 'much'] 1.8-3.2
# 6511 6512
# ['evidence'] 14.2
# 6514 6517
# ['effectiveness', 'of', 'some'] 1.6-9.7
# 6518 6520
# ['others.54,55', 'In'] 12.8 4.1
# 6521 6524
# ['the', 'finding', 'that'] 2.6-6.3
# 6526 6527
# ['fail'] 7.3
# 6528 6531
# ['receive', 'guideline-concordant', 'treatment,'] 3.0-17.6
# 6532 6533
# ['patients'] 12.1
# 6538 6540
# ['dropped', 'Table'] 13.0 2.4
# 6541 6544
# ['Lifetime', 'and', '12-Month'] 1.8-3.0
# 6545 6547
# ['of', 'Respondents'] 17.7 3.4
# 6548 6551
# ['4', 'Mutually', 'Exclusive'] 1.6-7.3
# 6552 6553
# ['Subgroups'] 17.5
# 6553 6554
# ['Treatment'] 3.6
# 6555 6558
# ['(Standard', 'Error)', '2'] 2.3-5.4
# 6559 6561
# ['*', 'PA'] 20.6 3.9
# 6562 6565
# ['PA-AG', 'PD', 'Only'] 2.1-7.2
# 6566 6567
# ['Lifetime'] 7.3
# 6567 6568
# ['treatment'] Illicit
# 6570 6572
# ['1672)', '(n'] 5.6 3.0
# 6573 6576
# ['71)', '(n', '='] 2.0-4.4
# 6578 6579
# ['='] 5.8
# 6580 6583
# ['Psychiatrist', '24.2', '(1.2)'] 2.1-16.0
# 6584 6586
# ['(6.6)', '37.9'] 9.1 5.2
# 6587 6590
# ['58.4', '(4.9)', '58.5'] 3.1-8.7
# 6594 6597
# ['(1.3)', '46.1', '(7.1)'] 1.9-10.9
# 6598 6599
# ['(2.8)'] 6.0
# 6603 6604
# ['medical'] 21.4
# 6604 6605
# ['32.3'] 2.2
# 6606 6609
# ['42.7', '(6.4)', '56.0'] 1.8-2.6
# 6611 6612
# ['(4.9)'] 3.5
# 6613 6616
# ['Human', 'services', '15.1'] 1.8-6.9
# 6617 6619
# ['26.6', '(6.1)'] 27.0 3.3
# 6624 6626
# ['Complementary-alternative', '15.9'] 37.3 4.8
# 6627 6630
# ['35.5', '(7.1)', '19.1'] 2.4-9.5
# 6631 6632
# ['28.3'] 9.8
# 6634 6636
# ['Panic-specific', 'treatment'] 71.9 3.3
# 6637 6640
# ['(1.2)', '37.6', '(6.6)'] 2.8-4.1
# 6641 6642
# ['(2.8)'] 100.0
# 6642 6645
# ['85.0', '(4.3)', '101.1'] NA 83.1 6.5
# 6646 6649
# ['treatment', '61.1', '(1.3)'] 3.7-11.7
# 6650 6651
# ['(5.4)'] 100.0
# 6651 6656
# ['84.8', '(1.8)', '96.1', '(1.7)', '107.5'] NA 5.3 Abbreviations: AG
# 6659 6660
# ['='] CI
# 6664 6665
# ['(n'] NA
# 6669 6670
# ['42)'] OR
# 6674 6675
# ['(7.4)'] PA
# 6679 6680
# ['24.7'] PD
# 6684 6685
# ['(1.4)'] PA
# 6690 6691
# ['(6.4)'] PA
# 6693 6696
# ['medical', '25.5', '(1.7)'] PD or AG
# 6697 6700
# ['(7.9)', '46.0', '(5.0)'] PA-AG
# 6704 6705
# ['services'] PA
# 6706 6707
# ['(1.2)'] AG
# 6709 6710
# ['12.7'] PD
# 6711 6712
# ['14.3'] PD
# 6717 6718
# ['11.7'] PD
# 6719 6720
# ['9.7'] AG
# 6721 6724
# ['15.9', '(5.8)', '7.5'] PD-AG
# 6728 6729
# ['29.7'] PD
# 6730 6731
# ['43.9'] AG
# 6753 6754
# ['(5.0)'] 4
# 6773 6775
# ['not', 'PD'] 5-year age
# 6793 6794
# ['without'] 4
# 6809 6810
# ['of'] P.05
# 6812 6813
# ['among'] 2-sided
# 6825 6828
# ['test.', '(REPRINTED)', 'ARCH'] PA-AG
# 6829 6832
# ['PSYCHIATRY/VOL', '63,', 'APR'] PD-AG
# 6834 6835
# ['422'] REPRINTED
# 6838 6842
# ['Association.', 'All', 'rights', 'reserved.'] PSYCHIATRY/VOL 63
# 6843 6845
# ['From:', 'http://archpsyc.jamanetwork.com/'] APR 2006
# 6846 6847
# ['04/10/2014'] 420
# 6848 6849
# ['of'] 2006
# 6849 6852
# ['treatment', 'prematurely', 'rather'] American Medical Association
# 6866 6867
# ['future'] 4
# 6869 6871
# ['Submitted', 'for'] 25.5%-46.0%
# 6889 6890
# ['PhD,'] 3
# 6892 6895
# ['Health', 'Care', 'Policy,'] PD or AG
# 6896 6898
# ['Medical', 'School,'] 40.6%-54.9%
# 6916 6917
# ['grant'] PA
# 6921 6923
# ['Institute', 'of'] 18.2%
# 6930 6933
# ['the', 'National', 'Institute'] PD and AG
# 6939 6940
# ['Abuse'] COMMENT
# 6951 6952
# ['Johnson'] First
# 6957 6960
# ['Alden', 'Trust.', 'Disclaimer:'] only 70%
# 6990 6991
# ['US'] 100
# 7039 7040
# ['Mark'] Second
# 7045 7047
# ['Institute,', 'College'] SCID PD
# 7057 7060
# ['Pincus', '(University', 'of'] PA or AG
# 7061 7062
# ['Pittsburgh,'] Third
# 7067 7068
# ['Cooperative,'] AOO
# 7096 7099
# ['Wittchen', '(Max', 'Planck'] NCS-R
# 7114 7115
# ['complete'] AOO
# 7137 7138
# ['The'] NCS
# 7144 7148
# ['the', 'World', 'Health', 'Organization'] DSM-IV PD
# 7149 7152
# ['Mental', 'Health', '(WMH)'] PD-AG
# 7153 7155
# ['Initiative.', 'These'] 4.7%
# 7156 7158
# ['were', 'supported'] 1.1%
# 7174 7175
# ['Foundation;'] NCS
# 7176 7178
# ['R13-MH066849,', 'R01-MH069864,'] 3.5%
# 7179 7181
# ['R01-DA016558', 'from'] 1.5%
# 7186 7187
# ['grant'] NCS
# 7191 7192
# ['Fogarty'] PD
# 7196 7198
# ['American', 'Health'] 3.7%
# 7205 7206
# ['Inc;'] NCS
# 7207 7208
# ['and'] 2.0%).2
# 7214 7215
# ['WMH'] surveys,31
# 7219 7223
# ['http://www', '.hcp.med.harvard.edu/wmh/.', 'Acknowledgment:', 'We'] NCS-R PD
# 7239 7240
# ['instrumentation,'] AG
# 7252 7253
# ['Zhao'] CIDI
# 7262 7266
# ['Kendler', 'KS.', 'Lifetime', 'and'] the DSM-IV
# 7284 7285
# ['Psychiatry.'] NCS1,2,32
# 7307 7308
# ['3.'] 4
# 7341 7342
# ['onset'] One
# 7354 7358
# ['5.', 'Kessler', 'RC.', 'The'] the NCS-R
# 7359 7361
# ['of', 'psychiatric'] 28.3%
# 7365 7366
# ['Sanderson'] NCS
# 7367 7369
# ['eds.', 'Treatment'] 7.3%
# 7382 7386
# ['1997.', '6.', 'Kessler', 'RC,'] the DSM-IV
# 7389 7390
# ['HU,'] CIDI
# 7407 7408
# ['1998;55:801-808.'] NCS
# 7430 7431
# ['with'] PD
# 7434 7435
# ['and'] AG
# 7454 7457
# ['in', 'the', 'community:'] DSM-IV
# 7476 7477
# ['GL.'] PD
# 7512 7513
# ['and'] PD
# 7527 7528
# ['attacks'] cues,38,39
# 7532 7533
# ['a'] NCS
# 7562 7563
# ['predictors.'] PD
# 7565 7566
# ['Psychopharmacol.'] AG
# 7581 7582
# ['Neufeld'] AG
# 7584 7585
# ['T,'] PD
# 7602 7603
# ['Br'] AG
# 7609 7610
# ['Berglund'] AG
# 7611 7612
# ['Chiu'] PD
# 7618 7622
# ['E,', 'Jin', 'R,', 'Pennell'] as about 40%
# 7626 7629
# ['A,', 'Zheng', 'H.'] PA and AG
# 7633 7634
# ['Survey'] PD
# 7647 7649
# ['16.', 'Kessler'] Table 4
# 7658 7659
# ['Initiative'] 4
# 7677 7678
# ['17.'] 701
# 7680 7683
# ['Abelson', 'J,', 'Demler'] PA-AG
# 7686 7687
# ['Gibbon'] 37
# 7694 7695
# ['Vega'] 120
# 7697 7700
# ['EE,', 'Wang', 'P,'] PD-AG
# 7703 7704
# ['H.'] 41
# 7709 7710
# ['in'] 0.3
# 7711 7712
# ['World'] 0.2
# 7713 7714
# ['Health'] 20.2
# 7715 7716
# ['version'] 7.1
# 7719 7720
# ['Health'] 2.5
# 7721 7722
# ['(WHO)'] 42.4
# 7723 7724
# ['International'] 8.0
# 7725 7726
# ['Interview'] 34.3
# 7727 7728
# ['Int'] 6.4
# 7729 7730
# ['Methods'] 0.8
# 7731 7732
# ['Res.'] 25.1
# 7733 7734
# ['18.'] 7.9
# 7735 7736
# ['RC,'] 40.1
# 7737 7738
# ['P,'] 4.8
# 7739 7740
# ['O,'] 43.9
# 7741 7742
# ['R,'] 10.1
# 7743 7744
# ['EE.'] 102.9
# 7745 7746
# ['prevalence'] 14.9
# 7747 7748
# ['age-of-onset'] 2.0
# 7749 7750
# ['of'] 25.1
# 7751 7752
# ['disorders'] 5.6
# 7753 7754
# ['the'] 37.8
# 7755 7756
# ['Comorbidity'] 5.7
# 7757 7758
# ['Replication.'] 13.7
# 7759 7760
# ['Gen'] 4.5
# 7761 7762
# ['2005;62:593-602.'] 61.9
# 7765 7766
# ['Spitzer'] 2.2
# 7767 7768
# ['Gibbon'] 29.6
# 7769 7770
# ['Williams'] 8.3
# 7771 7772
# ['Structured'] 16.1
# 7773 7774
# ['Interview'] 4.4
# 7781 7782
# ['Non-patient'] 1.1
# 7783 7784
# ['(SCID-I/NP).'] 39.0
# 7785 7786
# ['York:'] 7.9
# 7787 7788
# ['Research,'] 56.2
# 7789 7790
# ['York'] 5.0
# 7791 7792
# ['Psychiatric'] 84.7
# 7793 7794
# ['2002.'] 5.3
# 7795 7796
# ['Shear'] 108.4
# 7797 7798
# ['Rucci'] 10.2
# 7799 7800
# ['Williams'] 1.5
# 7801 7802
# ['Frank'] 19.8
# 7803 7804
# ['Grochocinski'] 8.0
# 7805 7806
# ['Vander'] 20.6
# 7807 7808
# ['J,'] 4.4
# 7811 7812
# ['T.'] 5.0
# 7813 7814
# ['and'] 119.8
# 7815 7816
# ['of'] 8.1
# 7817 7818
# ['Panic'] 1.2
# 7819 7820
# ['Severity'] 11.7
# 7821 7822
# ['replication'] 5.9
# 7825 7826
# ['Psychiatr'] 3.1
# 7827 7828
# ['2001;35:293-296.'] 5.0
# 7829 7830
# ['Houck'] 3.0
# 7831 7832
# ['Spiegel'] 62.9
# 7835 7836
# ['Rucci'] 2.0
# 7837 7838
# ['Reliability'] 29.4
# 7839 7840
# ['the'] 8.8
# 7841 7842
# ['version'] 9.4
# 7843 7844
# ['the'] 3.3
# 7849 7850
# ['Anxiety.'] AG
# 7853 7854
# ['AC,'] NA
# 7858 7859
# ['Farber'] PA
# 7863 7864
# ['psychiatric'] PD
# 7868 7869
# ['with'] PA
# 7874 7875
# ['J'] PA
# 7877 7880
# ['1997;27:93-105.', '23.', 'Wang'] PD or AG
# 7881 7884
# ['Berglund', 'P,', 'Olfson'] PA-AG
# 7888 7889
# ['KB,'] PA
# 7890 7891
# ['RC.'] AG
# 7893 7894
# ['delay'] PD
# 7895 7896
# ['initial'] PD
# 7901 7902
# ['of'] PD
# 7903 7904
# ['disorders'] AG
# 7905 7908
# ['the', 'National', 'Comorbidity'] PD-AG
# 7912 7913
# ['Psychiatry.'] PD
# 7914 7915
# ['24.'] AG
# 7926 7927
# ['Panic'] 12-month
# 7935 7937
# ['25.', 'Schatzberg'] Table 1
# 7942 7943
# ['of'] 12-month
# 7970 7974
# ['04/10/2014', '\x0c26.', 'Halli', 'SS,'] Panic Disorder Severity Scale
# 7993 7994
# ['Lemeshow'] P.05
# 7996 7997
# ['Logistic'] 2-sided
# 8003 8004
# ['John'] 4
# 8033 8034
# ['Triangle'] 4
# 8037 8039
# ['Triangle', 'Institute;'] Sheehan Disability
# 8078 8080
# ['RC,', 'Canino'] 2 3
# 8090 8093
# ['EG,', 'Lee', 'CK,'] the preceding row
# 8099 8103
# ['Oakley-Browne', 'MA,', 'RubioStipec', 'M,'] PSYCHIATRY/VOL 63
# 8104 8106
# ['JE,', 'Wickramaratne'] APR 2006
# 8106 8107
# ['PJ,'] WWW.ARCHGENPSYCHIATRY.COM
# 8107 8108
# ['Wittchen'] 421
# 8109 8110
# ['Yeh'] 2006
# 8110 8113
# ['EK.', 'The', 'cross-national'] American Medical Association
# 8124 8125
# ['Epidemiology']
# 8127 8128
# ['comorbidity.'] AG
# 8136 8139
# ['Textbook', 'in', 'Psychiatric'] PA-AG40
# 8144 8147
# ['Wiley', '&', 'Sons;'] PD-AG
# 8151 8152
# ['Bushnell'] PD
# 8159 8160
# ['The'] AG
# 8161 8162
# ['of'] PD
# 8182 8183
# ['N,'] AG
# 8186 8187
# ['co-morbidity'] PD
# 8188 8189
# ['correlates'] PA
# 8196 8197
# ['results'] AG
# 8198 8199
# ['the'] PD
# 8212 8213
# ['Angermeyer'] PA
# 8215 8218
# ['S,', 'Bruffaerts', 'R,'] PD-AG
# 8239 8242
# ['Lepine', 'JP,', 'Ormel'] PA-AG
# 8243 8244
# ['Polidori'] PD
# 8255 8256
# ['Bernal'] AG
# 8259 8260
# ['Codony'] PA
# 8276 8277
# ['P,'] PA
# 8278 8279
# ['C,'] PD
# 8324 8325
# ['36.'] PA
# 8327 8328
# ['Vermilyea'] PD
# 8375 8376
# ['In:'] PA
# 8377 8378
# ['KS,'] PD
# 8388 8389
# ['Oaks,'] PA
# 8396 8397
# ['Barlow'] PA
# 8400 8401
# ['and'] researchmightprofitablyattempttostudyPAonlyandevaluate
# 8408 8409
# ['Its'] PD
# 8426 8429
# ['40.', 'Crowe', 'RR,'] NCS-R
# 8439 8440
# ['panic'] PDSS
# 8452 8454
# ['agoraphobic', 'avoidance.'] 86.3%
# 8457 8460
# ['1988;2:203-217.', '42.', 'Wittchen'] PD-AG
# 8461 8463
# ['Essau', 'CA.'] 45.3%
# 8464 8466
# ['epidemiology', 'of'] 46.1%
# 8469 8472
# ['disorder,', 'and', 'agoraphobia.'] PA-AG
# 8473 8474
# ['Walker'] PD
# 8483 8484
# ['Agoraphobia:'] PDSS
# 8495 8496
# ['43.'] PDSS
# 8502 8503
# ['Rhodes'] SDS
# 8511 8516
# ['J', 'Abnorm', 'Psychol.', '1985;94:216-221.', '44.'] AG (PA-AG
# 8522 8523
# ['Factors'] PD
# 8524 8525
# ['with'] PD
# 8527 8528
# ['in'] PA
# 8539 8540
# ['DH.'] AG
# 8553 8556
# ['2001;108:4-32.', '46.', 'Clark'] severity41,47-49
# 8560 8561
# ['to'] AG
# 8567 8568
# ['Craske'] PD
# 8569 8570
# ['Barlow'] PA
# 8590 8591
# ['CF,'] AG
# 8594 8595
# ['CB.'] PA
# 8596 8597
# ['of'] PD
# 8599 8600
# ['in'] One
# 8607 8608
# ['Langs'] AG
# 8629 8630
# ['J'] AG
# 8633 8634
# ['50.'] PD
# 8640 8641
# ['Pincus'] AG
# 8655 8658
# ['States:', 'results', 'from'] NCS-R
# 8663 8664
# ['Arch'] PD
# 8683 8685
# ['J', 'Clin'] 45%-60%
# 8687 8688
# ['4):28-32.'] 3
# 8688 8691
# ['52.', 'Westen', 'D,'] PD and/or AG
# 8698 8699
# ['for'] guidelines.50
# 8744 8745
# ['A'] 53
# 8789 8790
# ['J'] 5
# 8791 8792
# ['2005;8:473-482.'] Lifetime
# 8793 8795
# ['ARCH', 'GEN'] 12-Month Treatment
# 8798 8799
# ['2006'] 4
# 8809 8811
# ['From:', 'http://archpsyc.jamanetwork.com/'] 2 3
# 8814 8817
# [] PA-AG
# 8819 8822
# [] PD-AG
# 8822 8823
# [] Lifetime
# 8827 8828
# [] 1672
# 8832 8833
# [] 71
# 8837 8838
# [] 344
# 8842 8843
# [] 105
# 8844 8845
# [] Psychiatrist
# 8845 8846
# [] 24.2
# 8847 8848
# [] 1.2
# 8849 8850
# [] 39.4
# 8851 8852
# [] 6.6
# 8853 8854
# [] 37.9
# 8855 8856
# [] 2.5
# 8857 8858
# [] 58.4
# 8859 8860
# [] 4.9
# 8861 8862
# [] 58.5
# 8865 8866
# [] 26.5
# 8867 8868
# [] 1.3
# ...
# 10170 10171
# [] Klerman
# 10180 10183
# [] Arch Gen Psychiatry
# 10184 10187
# [] 1989;46:984-992
# 10188 10189
# [] 10
# 10190 10192
# [] Wittchen HU
# 10193 10195
# [] Essau CA
# 10206 10209
# [] J Psychiatr Res
# 10210 10214
# [] 1993;27(suppl 1):47-68
# 10215 10216
# [] 11
# 10217 10219
# [] Goodwin RD
# 10220 10222
# [] Gotlib IH
# 10230 10233
# [] Acta Psychiatr Scand
# 10236 10237
# [] 221
# 10238 10239
# [] 12
# 10243 10245
# [] Wittchen HU
# 10246 10249
# [] DSM-IV
# 10274 10277
# [] 1998;32:335-345
# 10278 10279
# [] 13
# 10280 10283
# [] Katschnig H,
# 10283 10285
# [] Amering M.
# 10298 10300
# [] Clin Psychopharmacol
# 10302 10303
# [] 2):6S-11S.
# 10303 10304
# [] 14
# 10305 10307
# [] Eaton WW
# 10308 10310
# [] Anthony JC
# 10311 10312
# [] Romanoski
# 10314 10316
# [] Tien A
# 10317 10319
# [] Gallo J
# 10320 10322
# [] Cai G
# 10323 10324
# [] Neufeld
# 10329 10331
# [] Laugharne J
# 10332 10334
# [] Chen LS
# 10335 10336
# [] Onset
# 10342 10347
# [] the Baltimore Epidemiologic Catchment Area
# 10351 10354
# [] Br J Psychiatry
# 10355 10356
# [] 1998;173:501
# 10357 10358
# [] 507
# 10359 10360
# [] 15
# 10361 10363
# [] Kessler RC
# 10364 10366
# [] Berglund P
# 10367 10369
# [] Chiu WT
# 10370 10371
# [] Demler
# 10373 10375
# [] Heeringa S
# 10379 10381
# [] Jin R
# 10382 10384
# [] Pennell BE
# 10385 10387
# [] Walters EE
# 10388 10390
# [] Zaslavsky A
# 10391 10393
# [] Zheng H.
# 10394 10395
# [] US
# 10395 10399
# [] National Comorbidity Survey Replication
# 10400 10403
# [] NCS-R
# 10418 10421
# [] 13:69-92
# 10422 10423
# [] 16
# 10424 10426
# [] Kessler RC
# 10427 10429
# [] Ustun TB
# 10430 10448
# [] The World Mental Health (WMH) Survey Initiative Version of the World Health Organization (WHO)
# 10448 10452
# [] Composite International Diagnostic Interview
# 10466 10467
# [] 17
# 10468 10470
# [] Kessler RC
# 10471 10473
# [] Abelson J
# 10474 10476
# [] Demler O
# 10477 10479
# [] Escobar JI
# 10480 10485
# [] Gibbon M, Guyer ME
# 10486 10488
# [] Howes MJ
# 10489 10491
# [] Jin R
# 10492 10494
# [] Vega WA
# 10495 10497
# [] Walters EE
# 10498 10500
# [] Wang P
# 10501 10503
# [] Zaslavsky A
# 10504 10507
# [] Zheng H. Clinical
# 10509 10512
# [] DSM-IV
# 10514 10520
# [] the World Mental Health (WMH
# 10523 10527
# [] the World Health Organization
# 10530 10534
# [] Composite International Diagnostic Interview
# 10550 10552
# [] Kessler RC
# 10553 10555
# [] Berglund P
# 10556 10557
# [] Demler
# 10559 10561
# [] Jin R
# 10562 10564
# [] Walters EE
# 10565 10566
# [] Lifetime
# 10575 10578
# [] DSM-IV
# 10580 10585
# [] the National Comorbidity Survey Replication
# 10586 10589
# [] Arch Gen Psychiatry
# 10590 10593
# [] 2005;62:593-602
# 10594 10595
# [] 19
# 10596 10598
# [] First MB
# 10599 10601
# [] Spitzer RL
# 10602 10604
# [] Gibbon M
# 10605 10607
# [] Williams JBW
# 10608 10616
# [] Structured Clinical Interview for DSM-IV Axis
# 10619 10621
# [] Research Version
# 10622 10625
# [] Non-patient
# 10625 10632
# [] Edition (SCID-I/NP
# 10634 10639
# [] New York: Biometrics Research
# 10640 10645
# [] New York State Psychiatric Institute
# 10646 10647
# [] 2002
# 10648 10649
# [] 20
# 10650 10652
# [] Shear MK
# 10653 10655
# [] Rucci P
# 10656 10658
# [] Williams J
# 10659 10661
# [] Frank E
# 10662 10663
# [] Grochocinski
# 10665 10668
# [] Vander Bilt J
# 10669 10671
# [] Houck P
# 10672 10675
# [] Wang T. Reliability
# 10692 10695
# [] 2001;35:293-296
# 10696 10697
# [] 21
# 10698 10700
# [] Houck PR
# 10701 10703
# [] Spiegel DA
# 10704 10706
# [] Shear MK
# 10707 10710
# [] Rucci P. Reliability
# 10723 10725
# [] Depress Anxiety
# 10726 10727
# [] 2002;15:183
# 10730 10731
# [] 22
# 10732 10734
# [] Leon AC
# 10735 10737
# [] Olfson M
# 10738 10740
# [] Portera L
# 10741 10743
# [] Farber L
# 10747 10748
# [] Assessing
# 10761 10763
# [] Psychiatry Med
# 10764 10767
# [] 1997;27:93-105
# 10768 10769
# [] 23
# 10770 10772
# [] Wang PS
# 10773 10775
# [] Berglund P
# 10776 10778
# [] Olfson M
# 10779 10781
# [] Pincus HA
# 10782 10784
# [] Wells KB
# 10785 10787
# [] Kessler RC
# 10796 10797
# [] first
# 10802 10807
# [] the National Comorbidity Survey Replication
# 10808 10811
# [] Arch Gen Psychiatry
# 10816 10817
# [] 24
# 10818 10821
# [] American Psychiatric Association
# 10822 10824
# [] Practice Guideline
# 10825 10832
# [] the Treatment of Patients With Panic Disorder
# 10833 10834
# [] Washington
# 10835 10836
# [] DC
# 10837 10841
# [] American Psychiatric Association Press
# 10842 10843
# [] 1998
# 10844 10845
# [] 25
# 10846 10848
# [] Schatzberg AF
# 10849 10851
# [] Nemeroff CB
# 10854 10857
# [] Textbook of Psychopharmacology
# 10858 10859
# [] Washington
# 10860 10861
# [] DC
# 10862 10865
# [] American Psychiatric Publishing
# 10866 10867
# [] 2004
# 10869 10877
# [] REPRINTED) ARCH GEN PSYCHIATRY/VOL 63
# 10878 10879
# [] APR
# 10881 10882
# [] 423
# 10883 10884
# [] 2006
# 10884 10887
# [] American Medical Association
# 10899 10900
# [] 26
# 10901 10903
# [] Halli SS
# 10904 10906
# [] Rao KV
# 10907 10909
# [] Halli SS
# 10910 10915
# [] Advanced Techniques of Population Analysis
# 10916 10918
# [] New York
# 10919 10921
# [] NY:
# 10921 10924
# [] Plenum Publishing Corp
# 10925 10926
# [] 1992
# 10927 10928
# [] 27
# 10930 10931
# [] DW
# 10932 10937
# [] Lemeshow S. Applied Logistic Regression
# 10938 10939
# [] 2nd
# 10941 10943
# [] New York
# 10944 10945
# [] NY
# 10946 10950
# [] John Wiley & Sons
# 10951 10952
# [] 2000
# 10953 10954
# [] 28
# 10955 10957
# [] Wolter KM
# 10963 10965
# [] New York
# 10966 10967
# [] NY
# 10968 10973
# [] Springer-Verlag NY Inc
# 10974 10975
# [] 1985
# 10976 10977
# [] 29
# 10978 10979
# [] SUDAAN
# 10980 10986
# [] Professional Software for Survey Data Analysis
# 10987 10989
# [] Version 8.0.1
# 10991 10993
# [] Triangle Park
# 10994 10995
# [] NC
# 10996 10999
# [] Research Triangle Institute
# 11000 11001
# [] 2002
# 11002 11003
# [] 30
# 11004 11007
# [] Kna ¨uper B
# 11008 11010
# [] Cannell CF
# 11011 11013
# [] Schwarz N
# 11014 11016
# [] Bruce ML
# 11017 11019
# [] Kessler RC
# 11031 11036
# [] the US National Comorbidity Survey
# 11043 11046
# [] 1999;8:39-48
# 11047 11048
# [] 31
# 11049 11051
# [] Weissman MM
# 11052 11054
# [] Bland RC
# 11055 11057
# [] Canino GJ
# 11058 11060
# [] Faravelli C
# 11061 11063
# [] Greenwald S
# 11064 11066
# [] Hwu HG
# 11067 11069
# [] Joyce PR
# 11070 11072
# [] Karam EG
# 11073 11075
# [] Lee CK
# 11076 11078
# [] Lellouch J
# 11079 11081
# [] Lepine JP
# 11082 11084
# [] Newman SC
# 11085 11089
# [] Oakley-Browne MA
# 11090 11092
# [] RubioStipec M
# 11093 11095
# [] Wells JE
# 11096 11098
# [] Wickramaratne PJ
# 11099 11101
# [] Wittchen HU
# 11102 11104
# [] Yeh EK
# 11114 11117
# [] Arch Gen Psychiatry
# 11118 11121
# [] 1997;54:305-309
# 11122 11123
# [] 32
# 11124 11126
# [] Kessler RC
# 11134 11136
# [] Tsuang MT
# 11140 11142
# [] Zahner GEP
# 11145 11146
# [] Textbook
# 11147 11148
# [] Psychiatric
# 11150 11152
# [] New York
# 11153 11154
# [] NY
# 11155 11159
# [] John Wiley & Sons
# 11160 11161
# [] 1995:179
# 11162 11163
# [] 197
# 11164 11165
# [] 33
# 11166 11168
# [] Joyce PR
# 11170 11171
# [] JA
# 11172 11176
# [] Oakley-Browne MA
# 11177 11179
# [] Wells JE
# 11180 11182
# [] Hornblow AR
# 11192 11194
# [] Compr Psychiatry
# 11195 11196
# [] 1989;30:303
# 11197 11198
# [] 312
# 11199 11200
# [] 34
# 11201 11203
# [] Jacobi F
# 11204 11206
# [] Wittchen HU
# 11207 11209
# [] Holting C
# 11210 11212
# [] Hofler M
# 11216 11218
# [] Muller N
# 11219 11222
# [] Lieb R. Prevalence
# 11238 11245
# [] the German Health Interview and Examination Survey
# 11246 11247
# [] GHS
# 11249 11251
# [] Psychol Med
# 11252 11253
# [] 2004;34:597
# 11254 11255
# [] 611
# 11256 11257
# [] 35
# 11261 11263
# [] Angermeyer MC
# 11264 11266
# [] Bernert S
# 11267 11269
# [] Bruffaerts R
# 11270 11272
# [] Brugha TS
# 11273 11275
# [] Bryson H
# 11276 11279
# [] de Girolamo G
# 11280 11282
# [] Graaf R
# 11283 11285
# [] Demyttenaere K
# 11286 11288
# [] Gasquet I
# 11292 11294
# [] Katz SJ
# 11295 11297
# [] Kessler RC
# 11298 11300
# [] Kovess V
# 11301 11303
# [] Lepine JP
# 11304 11306
# [] Ormel J
# 11307 11309
# [] Polidori G
# 11310 11312
# [] Russo LJ
# 11313 11315
# [] Vilagut G
# 11316 11318
# [] Almansa J
# 11319 11323
# [] Arbabzadeh-Bouchez S
# 11324 11326
# [] Autonell J
# 11327 11329
# [] Bernal M
# 11330 11334
# [] Buist-Bouwman MA
# 11335 11337
# [] Codony M
# 11338 11345
# [] Domingo-Salvany A, Ferrer M
# 11346 11348
# [] Joo SS
# 11349 11350
# [] Martinez
# 11354 11356
# [] Matschinger H
# 11357 11359
# [] Mazzi F
# 11360 11362
# [] Morgan Z
# 11363 11365
# [] Morosini P
# 11366 11368
# [] Palacin C
# 11369 11371
# [] Romera B
# 11372 11374
# [] Taub N
# 11375 11377
# [] Vollebergh WA
# 11378 11379
# [] ESEMeD
# 11384 11392
# [] European Study of the Epidemiology of Mental Disorders
# 11404 11405
# [] Europe
# 11408 11418
# [] the European Study of the Epidemiology of Mental Disorders (
# 11422 11426
# [] Acta Psychiatr Scand Suppl
# 11427 11430
# [] 2004;420:28-37
# 11431 11432
# [] 36
# 11433 11435
# [] Barlow DH
# 11436 11438
# [] Vermilyea J
# 11439 11441
# [] Blanchard EB
# 11442 11444
# [] Vermilyea BB
# 11445 11448
# [] Di Nardo PA
# 11449 11451
# [] Cerny JA
# 11458 11460
# [] Abnorm Psychol
# 11461 11464
# [] 1985;94:320-328
# 11465 11466
# [] 37
# 11467 11469
# [] Craske MG
# 11470 11471
# [] Phobic
# 11485 11487
# [] Clin Psychol
# 11488 11489
# [] 1991;11:599
# 11490 11491
# [] 620
# 11492 11493
# [] 38
# 11494 11496
# [] Craske MG
# 11508 11510
# [] Dobson KS
# 11511 11513
# [] Craig KD
# 11518 11522
# [] Cognitive-Behavioral Therapy
# 11523 11525
# [] Vol 2
# 11526 11528
# [] Thousand Oaks
# 11529 11530
# [] Calif
# 11531 11533
# [] Sage Publications
# 11534 11537
# [] 1996:145-173
# 11538 11539
# [] 39
# 11540 11542
# [] White KS
# 11543 11545
# [] Barlow DH
# 11553 11555
# [] Barlow DH
# 11566 11571
# [] Treatment of Anxiety and Panic
# 11575 11577
# [] New York
# 11578 11579
# [] NY
# 11580 11582
# [] Guilford Publications
# 11583 11586
# [] 2002:328-379
# 11587 11588
# [] 40
# 11589 11591
# [] Crowe RR
# 11592 11594
# [] Noyes R
# 11595 11597
# [] Pauls DL
# 11598 11600
# [] Slymen D.
# 11607 11610
# [] Arch Gen Psychiatry
# 11611 11614
# [] 1983;40:1065-1069
# 11615 11616
# [] 41
# 11617 11618
# [] Rapee
# 11618 11619
# [] RM
# 11620 11623
# [] Murrell E. Predictors
# 11627 11630
# [] J Anxiety Disord
# 11631 11634
# [] 1988;2:203-217
# 11635 11636
# [] 42
# 11637 11641
# [] Wittchen H-U
# 11642 11644
# [] Essau CA
# 11659 11661
# [] Walker JR
# 11662 11664
# [] Norton GR
# 11665 11667
# [] Ross CA
# 11670 11672
# [] Panic Disorder
# 11673 11674
# [] Agoraphobia
# 11680 11681
# [] Practitioner
# 11682 11683
# [] Belmont
# 11684 11685
# [] Calif
# 11686 11688
# [] Brooks/ Cole
# 11689 11692
# [] 1991:103-149
# 11693 11694
# [] 43
# 11695 11697
# [] Norton GR
# 11698 11700
# [] Harrison B
# 11701 11703
# [] Hauch J
# 11704 11707
# [] Rhodes L. Characteristics
# 11715 11717
# [] Abnorm Psychol
# 11718 11721
# [] 1985;94:216-221
# 11722 11723
# [] 44
# 11724 11726
# [] Norton GR
# 11727 11729
# [] Dorward J
# 11730 11732
# [] Cox BJ
# 11733 11734
# [] Factors
# 11745 11746
# [] 1986;17:239
# 11747 11748
# [] 252
# 11749 11750
# [] 45
# 11751 11753
# [] Bouton ME
# 11754 11756
# [] Mineka S
# 11757 11759
# [] Barlow DH
# 11774 11777
# [] 2001;108:4-32
# 11778 11779
# [] 46
# 11780 11782
# [] Clark DM
# 11789 11792
# [] Behav Res Ther
# 11793 11794
# [] 1986;24:461
# 11797 11798
# [] 47
# 11799 11801
# [] Craske MG
# 11802 11804
# [] Barlow DH
# 11815 11817
# [] Clin Psychol
# 11818 11819
# [] 1988;8:667
# 11822 11823
# [] 48
# 11824 11826
# [] Telch MJ
# 11827 11829
# [] Brouillard M
# 11830 11832
# [] Telch CF
# 11833 11835
# [] Agras WS
# 11836 11838
# [] Taylor CB
# 11849 11852
# [] Behav Res Ther
# 11853 11856
# [] 1989;27:373-383
# 11857 11858
# [] 49
# 11859 11861
# [] Langs G
# 11862 11864
# [] Quehenberger F
# 11865 11867
# [] Fabisch K
# 11868 11870
# [] Klug G
# 11871 11873
# [] Fabisch H
# 11874 11876
# [] Zapotoczky HG
# 11890 11892
# [] Affect Disord
# 11893 11896
# [] 2000;58:43-50
# 11897 11898
# [] 50
# 11899 11901
# [] Wang PS
# 11902 11904
# [] Lane M
# 11905 11907
# [] Olfson M
# 11908 11910
# [] Pincus HA
# 11911 11913
# [] Wells KB
# 11914 11916
# [] Kessler RC
# 11917 11920
# [] Twelve-month
# 11926 11929
# [] the United States
# 11932 11937
# [] the National Comorbidity Survey Replication
# 11938 11941
# [] Arch Gen Psychiatry
# 11942 11943
# [] 2005;62:629
# 11944 11945
# [] 640
# 11946 11947
# [] 51
# 11948 11950
# [] Otto MW
# 11951 11954
# [] Deveney C. Cognitive
# 11969 11971
# [] Clin Psychiatry
# 11972 11973
# [] 2005;66(suppl
# 11973 11976
# [] 4):28-32
# 11977 11978
# [] 52
# 11979 11981
# [] Westen D
# 11982 11984
# [] Morrison K.
# 12013 12016
# [] Consult Clin Psychol
# 12017 12018
# [] 2001
# 12019 12020
# [] 69:875
# 12023 12024
# [] 53
# 12025 12027
# [] Milrod B
# 12028 12030
# [] Busch F
# 12031 12033
# [] Leon AC
# 12034 12035
# [] Aronson
# 12037 12039
# [] Roiphe J
# 12043 12045
# [] Singer M
# 12046 12048
# [] Shapiro T
# 12049 12051
# [] Goldman H
# 12055 12057
# [] Shear MK
# 12075 12076
# [] 2001;10
# 12077 12078
# [] 239
# 12081 12082
# [] 54
# 12083 12085
# [] Pollack MH
# 12093 12095
# [] Clin Psychiatry
# 12103 12104
# [] 55
# 12105 12106
# [] Bakker
# 12108 12111
# [] van Balkom AJ
# 12112 12114
# [] Stein DJ
# 12123 12126
# [] Int J Neuropsychopharmacol
# 12127 12128
# [] 2005;8:473
# 12132 12140
# [] REPRINTED) ARCH GEN PSYCHIATRY/VOL 63
# 12141 12142
# [] APR
# 12144 12145
# [] 424
# 12146 12147
# [] 2006
# 12147 12150
# [] American Medical Association
# ORIGINAL ARTICLE The Epidemiology of Panic Attacks, Panic Disorder, and Agoraphobia in the National Comorbidity Survey Replication Ronald C. Kessler, PhD; Wai Tat Chiu, AM; Robert Jin, MA; Ayelet Meron Ruscio, PhD; Katherine Shear, MD; Ellen E. Walters, MS Context: Only limited information exists about the epidemiology of DSM-IV panic attacks (PAs) and panic disorder (PD). Objective: To present nationally representative data about the epidemiology of PAs and PD with or without agoraphobia (AG) on the basis of the US National Comorbidity Survey Replication findings. Design and Setting: Nationally representative faceto-face household survey conducted using the fully structured World Health Organization Composite International Diagnostic Interview. Participants: English-speaking respondents (N=9282) 18 years or older. Main Outcome Measures: RespondentswhometDSMIV lifetime criteria for PAs and PD with and without AG. Results: Lifetime prevalence estimates are 22.7% for isolated panic without AG (PA only), 0.8% for PA with AG without PD (PA-AG), 3.7% for PD without AG (PD only), and 1.1% for PD with AG (PD-AG). Persistence, lifetime number of attacks, and number of years with attacks increase monotonically across these 4 subgroups. All 4 subgroups are significantly comorbid with other lifetime DSM-IV disorders, with the highest odds for PD-AG and the lowest for PA only. Scores on the Panic Disorder Severity Scale are also highest for PD-AG (86.3% moderate or severe) and lowest for PA only (6.7% moderate or severe). Agoraphobia is associated with substantial severity, impairment, and comorbidity. Lifetime treatment is high (from 96.1% for PD-AG to 61.1% for PA only), but 12-month treatment meeting published treatment guidelines is low (from 54.9% for PD-AG to 18.2% for PA only). Conclusion: Although the major societal burden of panic is caused by PD and PA-AG, isolated PAs also have high prevalence and meaningful role impairment. Arch Gen Psychiatry. 2006;63:415-424 EPIDEMIOLOGICAL SURVEY INvestigators have helped advance understanding of panic by studying the prevalence and distribution,1-3 onset and course,4 associations with comorbid disorders,5-7 and societal costs.8,9 Despite these advances, important questions remain unanswered about the epidemiology of panic,10 among the most important of them regarding the finding that many people have isolated panic attacks (PAs) that do not meet criteria for panic disorder (PD). These people have elevated prevalence of other mental disorders.6,11 They report greater impairment, use of psychotropic medication, and psychiatric help-seeking than people with many Axis I disorders.8 Such findings have led to the view that PAs are fairly nonspecific risk markers for psychopathology.12 Some people with isolated PAs meet criteria for agoraphobia (AG).13 It is not known, though, whether the persistent course and poor outcome associated with AG among people with PD14 also apply to PAs with AG. As a result, the boundary between PA and PD and the relative role of AG within each are not well understood. Investigation and comparison of these symptom presentations in community samplesmighthelpclarifytheseissues.The current report presents initial data of this sort from the recently completed US National Comorbidity Survey Replication (NCS-R). METHODS SAMPLE The NCS-R is a nationally representative survey of 9282 English-speaking household residents18yearsorolderinthecoterminousUnited States. Face-to-face interviews were performed between February 2001 and April 2003. The response rate was 70.9%. Consent was oral rather Author Affiliations: Department of Health Care Policy, Harvard Medical School, Boston, Mass (Drs Kessler and Ruscio, Messrs Chiu and Jin, and Ms Walters); and the Western Psychiatric Institute and Clinic, Pittsburgh, Pa (Dr Shear). (REPRINTED) ARCH GEN PSYCHIATRY/VOL 63, APR 2006 WWW.ARCHGENPSYCHIATRY.COM 415 ©2006 American Medical Association. All rights reserved. Downloaded From: http:// ...
